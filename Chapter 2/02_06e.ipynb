# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with yout API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to pull stock data with the alpha_vantage Python package 2

# %%
#get weekly stock data of Apple
ts1.get_weekly('AAPL')
# Out:
# ({'2023-04-21': {'1. open': '165.0900',
#    '2. high': '168.1600',
#    '3. low': '164.0300',
#    '4. close': '165.0200',
#    '5. volume': '249150510'},
#   '2023-04-14': {'1. open': '161.4200',
#    '2. high': '166.3200',
#    '3. low': '159.7800',
#    '4. close': '165.2100',
#    '5. volume': '263326290'},
#   '2023-04-06': {'1. open': '164.2700',
#    '2. high': '166.8400',
#    '3. low': '161.8000',
#    '4. close': '164.6600',
#    '5. volume': '200156349'},
#   '2023-03-31': {'1. open': '159.9400',
#    '2. high': '165.0000',
#    '3. low': '155.9800',
#    '4. close': '164.9000',
#    '5. volume': '267939590'},
#   '2023-03-24': {'1. open': '155.0700',
#    '2. high': '162.1400',
#    '3. low': '154.1500',
#    '4. close': '160.2500',
#    '5. volume': '350159914'},
#   '2023-03-17': {'1. open': '147.8050',
#    '2. high': '156.7400',
#    '3. low': '147.7000',
#    '4. close': '155.0000',
#    '5. volume': '410519933'},
#   '2023-03-10': {'1. open': '153.7850',
#    '2. high': '156.3000',
#    '3. low': '147.6096',
#    '4. close': '148.5000',
#    '5. volume': '313350829'},
#   '2023-03-03': {'1. open': '147.7100',
#    '2. high': '151.1100',
#    '3. low': '143.9000',
#    '4. close': '151.0300',
#    '5. volume': '274036517'},
#   '2023-02-24': {'1. open': '150.2000',
#    '2. high': '151.3000',
#    '3. low': '145.7202',
#    '4. close': '146.7100',
#    '5. volume': '213742390'},
#   '2023-02-17': {'1. open': '150.9520',
#    '2. high': '156.3300',
#    '3. low': '150.8500',
#    '4. close': '152.5500',
#    '5. volume': '316887898'},
#   '2023-02-10': {'1. open': '152.5750',
#    '2. high': '155.2300',
#    '3. low': '149.2200',
#    '4. close': '151.0100',
#    '5. volume': '330758787'},
#   '2023-02-03': {'1. open': '144.9550',
#    '2. high': '157.3800',
#    '3. low': '141.3200',
#    '4. close': '154.5000',
#    '5. volume': '480249683'},
#   '2023-01-27': {'1. open': '138.1200',
#    '2. high': '147.2300',
#    '3. low': '137.9000',
#    '4. close': '145.9300',
#    '5. volume': '338655715'},
#   '2023-01-20': {'1. open': '134.8300',
#    '2. high': '138.6100',
#    '3. low': '133.7700',
#    '4. close': '137.8700',
#    '5. volume': '271823466'},
#   '2023-01-13': {'1. open': '130.4650',
#    '2. high': '134.9200',
#    '3. low': '128.1200',
#    '4. close': '134.7600',
#    '5. volume': '333335284'},
#   '2023-01-06': {'1. open': '130.2800',
#    '2. high': '130.9000',
#    '3. low': '124.1700',
#    '4. close': '129.6200',
#    '5. volume': '369948527'},
#   '2022-12-30': {'1. open': '131.3800',
#    '2. high': '131.4100',
#    '3. low': '125.8700',
#    '4. close': '129.9300',
#    '5. volume': '307184140'},
#   '2022-12-23': {'1. open': '135.1100',
#    '2. high': '136.8100',
#    '3. low': '129.6400',
#    '4. close': '131.8600',
#    '5. volume': '384620427'},
#   '2022-12-16': {'1. open': '142.7000',
#    '2. high': '149.9692',
#    '3. low': '133.7300',
#    '4. close': '134.5100',
#    '5. volume': '505728804'},
#   '2022-12-09': {'1. open': '147.7700',
#    '2. high': '150.9199',
#    '3. low': '140.0000',
#    '4. close': '142.1600',
#    '5. volume': '341500071'},
#   '2022-12-02': {'1. open': '145.1400',
#    '2. high': '149.1300',
#    '3. low': '140.3550',
#    '4. close': '147.8100',
#    '5. volume': '401189067'},
#   '2022-11-25': {'1. open': '150.1600',
#    '2. high': '151.8300',
#    '3. low': '146.9250',
#    '4. close': '148.1100',
#    '5. volume': '204025457'},
#   '2022-11-18': {'1. open': '148.9700',
#    '2. high': '153.5900',
#    '3. low': '146.1500',
#    '4. close': '151.2900',
#    '5. volume': '382679685'},
#   '2022-11-11': {'1. open': '137.1100',
#    '2. high': '150.0100',
#    '3. low': '134.5933',
#    '4. close': '149.7000',
#    '5. volume': '461034592'},
#   '2022-11-04': {'1. open': '153.1550',
#    '2. high': '155.4500',
#    '3. low': '134.3800',
#    '4. close': '138.3800',
#    '5. volume': '510660451'},
#   '2022-10-28': {'1. open': '147.1850',
#    '2. high': '157.5000',
#    '3. low': '144.1300',
#    '4. close': '155.7400',
#    '5. volume': '513092901'},
#   '2022-10-21': {'1. open': '141.0650',
#    '2. high': '147.8479',
#    '3. low': '140.2700',
#    '4. close': '147.2700',
#    '5. volume': '397216487'},
#   '2022-10-14': {'1. open': '140.4200',
#    '2. high': '144.5200',
#    '3. low': '134.3700',
#    '4. close': '138.3800',
#    '5. volume': '424188362'},
#   '2022-10-07': {'1. open': '138.2100',
#    '2. high': '147.5400',
#    '3. low': '137.6850',
#    '4. close': '140.0900',
#    '5. volume': '435940423'},
#   '2022-09-30': {'1. open': '149.6600',
#    '2. high': '154.7200',
#    '3. low': '138.0000',
#    '4. close': '138.2000',
#    '5. volume': '577537048'},
#   '2022-09-23': {'1. open': '149.3100',
#    '2. high': '158.7400',
#    '3. low': '148.5600',
#    '4. close': '150.4300',
#    '5. volume': '473155533'},
#   '2022-09-16': {'1. open': '159.5900',
#    '2. high': '164.2600',
#    '3. low': '148.3700',
#    '4. close': '150.7000',
#    '5. volume': '568337936'},
#   '2022-09-09': {'1. open': '156.4700',
#    '2. high': '157.8200',
#    '3. low': '152.6800',
#    '4. close': '157.3700',
#    '5. volume': '313749966'},
#   '2022-09-02': {'1. open': '161.1450',
#    '2. high': '162.9000',
#    '3. low': '154.6700',
#    '4. close': '155.8100',
#    '5. volume': '389809404'},
#   '2022-08-26': {'1. open': '169.6900',
#    '2. high': '171.0500',
#    '3. low': '163.5600',
#    '4. close': '163.6200',
#    '5. volume': '307194601'},
#   '2022-08-19': {'1. open': '171.5200',
#    '2. high': '176.1500',
#    '3. low': '171.3101',
#    '4. close': '171.5200',
#    '5. volume': '322647151'},
#   '2022-08-12': {'1. open': '166.3700',
#    '2. high': '172.1700',
#    '3. low': '163.2500',
#    '4. close': '172.1000',
#    '5. volume': '318856922'},
#   '2022-08-05': {'1. open': '161.0100',
#    '2. high': '167.1900',
#    '3. low': '159.6300',
#    '4. close': '165.3500',
#    '5. volume': '322415021'},
#   '2022-07-29': {'1. open': '154.0100',
#    '2. high': '163.6300',
#    '3. low': '150.8000',
#    '4. close': '162.5100',
#    '5. volume': '370548915'},
#   '2022-07-22': {'1. open': '150.7400',
#    '2. high': '156.2800',
#    '3. low': '146.7000',
#    '4. close': '154.0900',
#    '5. volume': '360988692'},
#   '2022-07-15': {'1. open': '145.6700',
#    '2. high': '150.8600',
#    '3. low': '142.1201',
#    '4. close': '150.1700',
#    '5. volume': '366480107'},
#   '2022-07-08': {'1. open': '137.7700',
#    '2. high': '147.5500',
#    '3. low': '136.9300',
#    '4. close': '147.0400',
#    '5. volume': '278295402'},
#   '2022-07-01': {'1. open': '142.6950',
#    '2. high': '143.4900',
#    '3. low': '133.7737',
#    '4. close': '138.9300',
#    '5. volume': '373781666'},
#   '2022-06-24': {'1. open': '133.4200',
#    '2. high': '141.9100',
#    '3. low': '133.3200',
#    '4. close': '141.6600',
#    '5. volume': '315960327'},
#   '2022-06-17': {'1. open': '132.8700',
#    '2. high': '137.3400',
#    '3. low': '129.0400',
#    '4. close': '131.5600',
#    '5. volume': '541006195'},
#   '2022-06-10': {'1. open': '147.0300',
#    '2. high': '149.8697',
#    '3. low': '137.0600',
#    '4. close': '137.1300',
#    '5. volume': '354396344'},
#   '2022-06-03': {'1. open': '149.0700',
#    '2. high': '151.7400',
#    '3. low': '144.4600',
#    '4. close': '145.3800',
#    '5. volume': '338923395'},
#   '2022-05-27': {'1. open': '137.7900',
#    '2. high': '149.6800',
#    '3. low': '137.1400',
#    '4. close': '149.6400',
#    '5. volume': '495921758'},
#   '2022-05-20': {'1. open': '145.5500',
#    '2. high': '149.7700',
#    '3. low': '132.6100',
#    '4. close': '137.5900',
#    '5. volume': '548244690'},
#   '2022-05-13': {'1. open': '154.9250',
#    '2. high': '156.7400',
#    '3. low': '138.8000',
#    '4. close': '147.1100',
#    '5. volume': '686227375'},
#   '2022-05-06': {'1. open': '156.7100',
#    '2. high': '166.4800',
#    '3. low': '153.2700',
#    '4. close': '157.2800',
#    '5. volume': '566193362'},
#   '2022-04-29': {'1. open': '161.1200',
#    '2. high': '166.2000',
#    '3. low': '155.3800',
#    '4. close': '157.6500',
#    '5. volume': '540082324'},
#   '2022-04-22': {'1. open': '163.9200',
#    '2. high': '171.5300',
#    '3. low': '161.5000',
#    '4. close': '161.7900',
#    '5. volume': '376576076'},
#   '2022-04-14': {'1. open': '168.7100',
#    '2. high': '171.2700',
#    '3. low': '165.0400',
#    '4. close': '165.2900',
#    '5. volume': '297460188'},
#   '2022-04-08': {'1. open': '174.5700',
#    '2. high': '178.4900',
#    '3. low': '169.2000',
#    '4. close': '170.0900',
#    '5. volume': '390677922'},
#   '2022-04-01': {'1. open': '172.1700',
#    '2. high': '179.6100',
#    '3. low': '171.9400',
#    '4. close': '174.3100',
#    '5. volume': '465395123'},
#   '2022-03-25': {'1. open': '163.5100',
#    '2. high': '175.2800',
#    '3. low': '163.0150',
#    '4. close': '174.7200',
#    '5. volume': '438484780'},
#   '2022-03-18': {'1. open': '151.4500',
#    '2. high': '164.4800',
#    '3. low': '150.1000',
#    '4. close': '163.9800',
#    '5. volume': '501667481'},
#   '2022-03-11': {'1. open': '163.3600',
#    '2. high': '165.0200',
#    '3. low': '154.5000',
#    '4. close': '154.7300',
#    '5. volume': '521334165'},
#   '2022-03-04': {'1. open': '163.0600',
#    '2. high': '168.9100',
#    '3. low': '161.9700',
#    '4. close': '163.1700',
#    '5. volume': '418753837'},
#   '2022-02-25': {'1. open': '164.9800',
#    '2. high': '166.6900',
#    '3. low': '152.0000',
#    '4. close': '164.8500',
#    '5. volume': '413588646'},
#   '2022-02-18': {'1. open': '167.3700',
#    '2. high': '173.3400',
#    '3. low': '166.1900',
#    '4. close': '167.3000',
#    '5. volume': '364011266'},
#   '2022-02-11': {'1. open': '172.8600',
#    '2. high': '176.6500',
#    '3. low': '168.0400',
#    '4. close': '168.6400',
#    '5. volume': '412902045'},
#   '2022-02-04': {'1. open': '170.1600',
#    '2. high': '176.2399',
#    '3. low': '169.5100',
#    '4. close': '172.3900',
#    '5. volume': '458553231'},
#   '2022-01-28': {'1. open': '160.0200',
#    '2. high': '170.3500',
#    '3. low': '154.7000',
#    '4. close': '170.3300',
#    '5. volume': '688670659'},
#   '2022-01-21': {'1. open': '171.5100',
#    '2. high': '172.5400',
#    '3. low': '162.3000',
#    '4. close': '162.4100',
#    '5. volume': '397684401'},
#   '2022-01-14': {'1. open': '169.0800',
#    '2. high': '177.1800',
#    '3. low': '168.1700',
#    '4. close': '173.0700',
#    '5. volume': '422454950'},
#   '2022-01-07': {'1. open': '177.8300',
#    '2. high': '182.9400',
#    '3. low': '171.0300',
#    '4. close': '172.1700',
#    '5. volume': '482162362'},
#   '2021-12-31': {'1. open': '177.0850',
#    '2. high': '181.3300',
#    '3. low': '177.0700',
#    '4. close': '177.5700',
#    '5. volume': '337847299'},
#   '2021-12-23': {'1. open': '168.2800',
#    '2. high': '176.8499',
#    '3. low': '167.4600',
#    '4. close': '176.2800',
#    '5. volume': '359176889'},
#   '2021-12-17': {'1. open': '181.1150',
#    '2. high': '182.1300',
#    '3. low': '169.6900',
#    '4. close': '171.1400',
#    '5. volume': '769789942'},
#   '2021-12-10': {'1. open': '164.2900',
#    '2. high': '179.6300',
#    '3. low': '164.2800',
#    '4. close': '179.4500',
#    '5. volume': '569227705'},
#   '2021-12-03': {'1. open': '159.3700',
#    '2. high': '170.3000',
#    '3. low': '157.8000',
#    '4. close': '161.8400',
#    '5. volume': '669981566'},
#   '2021-11-26': {'1. open': '161.6800',
#    '2. high': '165.7000',
#    '3. low': '156.3600',
#    '4. close': '156.8100',
#    '5. volume': '359933163'},
#   '2021-11-19': {'1. open': '150.3700',
#    '2. high': '161.0200',
#    '3. low': '149.3400',
#    '4. close': '160.5500',
#    '5. volume': '462419283'},
#   '2021-11-12': {'1. open': '151.4100',
#    '2. high': '151.5700',
#    '3. low': '147.4800',
#    '4. close': '149.9900',
#    '5. volume': '281026556'},
#   '2021-11-05': {'1. open': '148.9850',
#    '2. high': '152.4300',
#    '3. low': '147.8000',
#    '4. close': '151.2800',
#    '5. volume': '322688958'},
#   '2021-10-29': {'1. open': '148.6800',
#    '2. high': '153.1650',
#    '3. low': '146.4128',
#    '4. close': '149.8000',
#    '5. volume': '392739936'},
#   '2021-10-22': {'1. open': '143.4450',
#    '2. high': '150.1800',
#    '3. low': '143.1600',
#    '4. close': '148.6900',
#    '5. volume': '340691290'},
#   '2021-10-15': {'1. open': '142.2700',
#    '2. high': '144.8950',
#    '3. low': '139.2000',
#    '4. close': '144.8400',
#    '5. volume': '354098233'},
#   '2021-10-08': {'1. open': '141.7600',
#    '2. high': '144.2150',
#    '3. low': '138.2700',
#    '4. close': '142.9000',
#    '5. volume': '382910000'},
#   '2021-10-01': {'1. open': '145.4700',
#    '2. high': '145.9600',
#    '3. low': '139.1101',
#    '4. close': '142.6500',
#    '5. volume': '441421358'},
#   '2021-09-24': {'1. open': '143.8000',
#    '2. high': '147.4701',
#    '3. low': '141.2700',
#    '4. close': '146.9200',
#    '5. volume': '394033205'},
#   '2021-09-17': {'1. open': '150.6300',
#    '2. high': '151.4200',
#    '3. low': '145.7600',
#    '4. close': '146.0600',
#    '5. volume': '492884912'},
#   '2021-09-10': {'1. open': '154.9700',
#    '2. high': '157.2600',
#    '3. low': '148.7000',
#    '4. close': '148.9700',
#    '5. volume': '354897433'},
#   '2021-09-03': {'1. open': '149.0000',
#    '2. high': '154.9800',
#    '3. low': '148.6100',
#    '4. close': '154.3000',
#    '5. volume': '386760934'},
#   '2021-08-27': {'1. open': '148.3100',
#    '2. high': '150.8600',
#    '3. low': '146.8300',
#    '4. close': '148.6000',
#    '5. volume': '272129118'},
#   '2021-08-20': {'1. open': '148.5350',
#    '2. high': '151.6800',
#    '3. low': '144.5000',
#    '4. close': '148.1900',
#    '5. volume': '429624447'},
#   '2021-08-13': {'1. open': '146.2000',
#    '2. high': '149.4444',
#    '3. low': '145.3000',
#    '4. close': '149.1000',
#    '5. volume': '299050639'},
#   '2021-08-06': {'1. open': '146.3600',
#    '2. high': '148.0450',
#    '3. low': '145.1800',
#    '4. close': '146.1400',
#    '5. volume': '284559337'},
#   '2021-07-30': {'1. open': '148.2700',
#    '2. high': '149.8300',
#    '3. low': '142.5400',
#    '4. close': '145.8600',
#    '5. volume': '420947531'},
#   '2021-07-23': {'1. open': '143.7500',
#    '2. high': '148.7177',
#    '3. low': '141.6700',
#    '4. close': '148.5600',
#    '5. volume': '441563639'},
#   '2021-07-16': {'1. open': '146.2100',
#    '2. high': '150.0000',
#    '3. low': '143.6300',
#    '4. close': '146.3900',
#    '5. volume': '504249326'},
#   '2021-07-09': {'1. open': '140.0700',
#    '2. high': '145.6500',
#    '3. low': '140.0700',
#    '4. close': '145.1100',
#    '5. volume': '418559640'},
#   '2021-07-02': {'1. open': '133.4100',
#    '2. high': '140.0000',
#    '3. low': '133.3500',
#    '4. close': '139.9600',
#    '5. volume': '321360130'},
#   '2021-06-25': {'1. open': '130.3000',
#    '2. high': '134.6400',
#    '3. low': '129.2100',
#    '4. close': '133.1100',
#    '5. volume': '354155878'},
#   '2021-06-18': {'1. open': '127.8200',
#    '2. high': '132.5500',
#    '3. low': '127.0700',
#    '4. close': '130.4600',
#    '5. volume': '456667151'},
#   '2021-06-11': {'1. open': '126.1700',
#    '2. high': '128.4600',
#    '3. low': '124.8321',
#    '4. close': '127.3500',
#    '5. volume': '327048055'},
#   '2021-06-04': {'1. open': '125.0800',
#    '2. high': '126.1600',
#    '3. low': '123.1300',
#    '4. close': '125.8900',
#    '5. volume': '278314493'},
#   '2021-05-28': {'1. open': '126.0100',
#    '2. high': '128.3200',
#    '3. low': '124.5500',
#    '4. close': '124.6100',
#    '5. volume': '357615057'},
#   '2021-05-21': {'1. open': '126.8200',
#    '2. high': '128.0000',
#    '3. low': '122.8600',
#    '4. close': '125.4300',
#    '5. volume': '386352101'},
#   '2021-05-14': {'1. open': '129.4100',
#    '2. high': '129.5400',
#    '3. low': '122.2500',
#    '4. close': '127.4500',
#    '5. volume': '514165627'},
#   '2021-05-07': {'1. open': '132.0400',
#    '2. high': '134.0700',
#    '3. low': '126.7000',
#    '4. close': '130.2100',
#    '5. volume': '453802325'},
#   '2021-04-30': {'1. open': '134.8300',
#    '2. high': '137.0700',
#    '3. low': '131.0650',
#    '4. close': '131.4600',
#    '5. volume': '501621389'},
#   '2021-04-23': {'1. open': '133.5100',
#    '2. high': '135.5300',
#    '3. low': '131.3001',
#    '4. close': '134.3200',
#    '5. volume': '421246935'},
#   '2021-04-16': {'1. open': '132.5200',
#    '2. high': '135.0000',
#    '3. low': '130.6300',
#    '4. close': '134.1600',
#    '5. volume': '444178798'},
#   '2021-04-09': {'1. open': '123.8700',
#    '2. high': '133.0400',
#    '3. low': '123.0700',
#    '4. close': '132.9950',
#    '5. volume': '447820438'},
#   '2021-04-01': {'1. open': '121.6500',
#    '2. high': '124.1800',
#    '3. low': '118.8600',
#    '4. close': '123.0000',
#    '5. volume': '359904082'},
#   '2021-03-26': {'1. open': '120.3300',
#    '2. high': '124.2400',
#    '3. low': '118.9200',
#    '4. close': '121.2100',
#    '5. volume': '488825826'},
#   '2021-03-19': {'1. open': '121.4100',
#    '2. high': '127.2200',
#    '3. low': '119.6750',
#    '4. close': '119.9900',
#    '5. volume': '626770404'},
#   '2021-03-12': {'1. open': '120.9300',
#    '2. high': '123.2100',
#    '3. low': '116.2100',
#    '4. close': '121.0300',
#    '5. volume': '586977280'},
#   '2021-03-05': {'1. open': '123.7500',
#    '2. high': '128.7200',
#    '3. low': '117.5700',
#    '4. close': '121.4200',
#    '5. volume': '663456753'},
#   '2021-02-26': {'1. open': '128.0100',
#    '2. high': '129.7200',
#    '3. low': '118.3900',
#    '4. close': '121.2600',
#    '5. volume': '680391444'},
#   '2021-02-19': {'1. open': '135.4900',
#    '2. high': '136.0100',
#    '3. low': '127.4100',
#    '4. close': '129.8700',
#    '5. volume': '362474097'},
#   '2021-02-12': {'1. open': '136.0300',
#    '2. high': '137.8770',
#    '3. low': '133.6921',
#    '4. close': '135.3700',
#    '5. volume': '344357350'},
#   '2021-02-05': {'1. open': '133.7500',
#    '2. high': '137.4200',
#    '3. low': '130.9300',
#    '4. close': '136.7600',
#    '5. volume': '438264070'},
#   '2021-01-29': {'1. open': '143.0700',
#    '2. high': '145.0900',
#    '3. low': '130.2100',
#    '4. close': '131.9600',
#    '5. volume': '716990967'},
#   '2021-01-22': {'1. open': '127.7800',
#    '2. high': '139.8500',
#    '3. low': '126.9380',
#    '4. close': '139.0700',
#    '5. volume': '430065722'},
#   '2021-01-15': {'1. open': '129.1900',
#    '2. high': '131.4500',
#    '3. low': '126.8600',
#    '4. close': '127.1400',
#    '5. volume': '481518252'},
#   '2021-01-08': {'1. open': '133.5200',
#    '2. high': '133.6116',
#    '3. low': '126.3820',
#    '4. close': '132.0500',
#    '5. volume': '610791157'},
#   '2020-12-31': {'1. open': '133.9900',
#    '2. high': '138.7890',
#    '3. low': '131.7200',
#    '4. close': '132.6900',
#    '5. volume': '439740666'},
#   '2020-12-24': {'1. open': '125.0200',
#    '2. high': '134.4050',
#    '3. low': '123.4490',
#    '4. close': '131.9700',
#    '5. volume': '433757134'},
#   '2020-12-18': {'1. open': '122.6000',
#    '2. high': '129.5800',
#    '3. low': '121.5400',
#    '4. close': '126.6550',
#    '5. volume': '621758148'},
#   '2020-12-11': {'1. open': '122.3100',
#    '2. high': '125.9500',
#    '3. low': '120.1500',
#    '4. close': '122.4100',
#    '5. volume': '452278651'},
#   '2020-12-04': {'1. open': '116.9700',
#    '2. high': '123.7800',
#    '3. low': '116.8100',
#    '4. close': '122.2500',
#    '5. volume': '541563385'},
#   '2020-11-27': {'1. open': '117.1800',
#    '2. high': '117.6202',
#    '3. low': '112.5900',
#    '4. close': '116.5900',
#    '5. volume': '364376131'},
#   '2020-11-20': {'1. open': '118.9200',
#    '2. high': '120.9900',
#    '3. low': '116.8100',
#    '4. close': '117.3400',
#    '5. volume': '389493361'},
#   '2020-11-13': {'1. open': '120.5000',
#    '2. high': '121.9900',
#    '3. low': '114.1300',
#    '4. close': '119.2600',
#    '5. volume': '589872919'},
#   '2020-11-06': {'1. open': '109.1100',
#    '2. high': '119.6200',
#    '3. low': '107.3200',
#    '4. close': '118.6900',
#    '5. volume': '609571825'},
#   '2020-10-30': {'1. open': '114.0100',
#    '2. high': '117.2800',
#    '3. low': '107.7200',
#    '4. close': '108.8600',
#    '5. volume': '684767901'},
#   '2020-10-23': {'1. open': '119.9600',
#    '2. high': '120.4190',
#    '3. low': '114.2800',
#    '4. close': '115.0400',
#    '5. volume': '519569644'},
#   '2020-10-16': {'1. open': '120.0600',
#    '2. high': '125.3900',
#    '3. low': '118.1500',
#    '4. close': '119.0200',
#    '5. volume': '881572555'},
#   '2020-10-09': {'1. open': '113.9100',
#    '2. high': '117.0000',
#    '3. low': '112.2500',
#    '4. close': '116.9700',
#    '5. volume': '548575054'},
#   '2020-10-02': {'1. open': '115.0100',
#    '2. high': '117.7200',
#    '3. low': '112.2200',
#    '4. close': '113.0200',
#    '5. volume': '641240539'},
#   '2020-09-25': {'1. open': '104.5400',
#    '2. high': '112.8600',
#    '3. low': '103.1000',
#    '4. close': '112.2800',
#    '5. volume': '847212649'},
#   '2020-09-18': {'1. open': '114.7200',
#    '2. high': '118.8290',
#    '3. low': '106.0900',
#    '4. close': '106.8400',
#    '5. volume': '944934651'},
#   '2020-09-11': {'1. open': '113.9500',
#    '2. high': '120.5000',
#    '3. low': '110.0000',
#    '4. close': '112.0000',
#    '5. volume': '771441734'},
#   '2020-09-04': {'1. open': '127.5800',
#    '2. high': '137.9800',
#    '3. low': '110.8900',
#    '4. close': '120.9600',
#    '5. volume': '1166301669'},
#   '2020-08-28': {'1. open': '514.7900',
#    '2. high': '515.1400',
#    '3. low': '492.2100',
#    '4. close': '499.2300',
#    '5. volume': '265909531'},
#   '2020-08-21': {'1. open': '464.2500',
#    '2. high': '499.4720',
#    '3. low': '455.8501',
#    '4. close': '497.4800',
#    '5. volume': '208464758'},
#   '2020-08-14': {'1. open': '450.4000',
#    '2. high': '464.1700',
#    '3. low': '436.4267',
#    '4. close': '459.6300',
#    '5. volume': '235474473'},
#   '2020-08-07': {'1. open': '432.8000',
#    '2. high': '457.6500',
#    '3. low': '431.5700',
#    '4. close': '444.4500',
#    '5. volume': '250852555'},
#   '2020-07-31': {'1. open': '374.8400',
#    '2. high': '425.6600',
#    '3. low': '372.9900',
#    '4. close': '425.0400',
#    '5. volume': '211898609'},
#   '2020-07-24': {'1. open': '385.6700',
#    '2. high': '397.0000',
#    '3. low': '356.5800',
#    '4. close': '370.4600',
#    '5. volume': '165885792'},
#   '2020-07-17': {'1. open': '389.0600',
#    '2. high': '399.8200',
#    '3. low': '375.5100',
#    '4. close': '385.3100',
#    '5. volume': '179660754'},
#   '2020-07-10': {'1. open': '370.0000',
#    '2. high': '385.2700',
#    '3. low': '369.8700',
#    '4. close': '383.6800',
#    '5. volume': '141212101'},
#   '2020-07-02': {'1. open': '353.2500',
#    '2. high': '370.4700',
#    '3. low': '351.2800',
#    '4. close': '364.1100',
#    '5. volume': '124222310'},
#   '2020-06-26': {'1. open': '351.3400',
#    '2. high': '372.3800',
#    '3. low': '351.1500',
#    '4. close': '353.6300',
#    '5. volume': '220750873'},
#   '2020-06-19': {'1. open': '333.2500',
#    '2. high': '356.5600',
#    '3. low': '332.5800',
#    '4. close': '349.7200',
#    '5. volume': '194985086'},
#   '2020-06-12': {'1. open': '330.2500',
#    '2. high': '354.7700',
#    '3. low': '327.3200',
#    '4. close': '338.8000',
#    '5. volume': '202956789'},
#   '2020-06-05': {'1. open': '317.7500',
#    '2. high': '331.7500',
#    '3. low': '317.2100',
#    '4. close': '331.5000',
#    '5. volume': '124490802'},
#   '2020-05-29': {'1. open': '323.5000',
#    '2. high': '324.2400',
#    '3. low': '313.0900',
#    '4. close': '317.9400',
#    '5. volume': '131465363'},
#   '2020-05-22': {'1. open': '313.1700',
#    '2. high': '320.8900',
#    '3. low': '310.3200',
#    '4. close': '318.8900',
#    '5. volume': '133274690'},
#   '2020-05-15': {'1. open': '308.1000',
#    '2. high': '319.6900',
#    '3. low': '300.2100',
#    '4. close': '307.7100',
#    '5. volume': '208536826'},
#   '2020-05-08': {'1. open': '289.1700',
#    '2. high': '310.3500',
#    '3. low': '286.3200',
#    '4. close': '310.1300',
#    '5. volume': '168228968'},
#   '2020-05-01': {'1. open': '281.8000',
#    '2. high': '299.0000',
#    '3. low': '278.2000',
#    '4. close': '289.0700',
#    '5. volume': '197513427'},
#   '2020-04-24': {'1. open': '277.9500',
#    '2. high': '283.0100',
#    '3. low': '265.4300',
#    '4. close': '282.9700',
#    '5. volume': '169846750'},
#   '2020-04-17': {'1. open': '268.3100',
#    '2. high': '288.2500',
#    '3. low': '265.8300',
#    '4. close': '282.8000',
#    '5. volume': '207386812'},
#   '2020-04-09': {'1. open': '250.9000',
#    '2. high': '271.7000',
#    '3. low': '249.3800',
#    '4. close': '267.9900',
#    '5. volume': '183929846'},
#   '2020-04-03': {'1. open': '250.7400',
#    '2. high': '262.4900',
#    '3. low': '236.9000',
#    '4. close': '241.4100',
#    '5. volume': '209252759'},
#   '2020-03-27': {'1. open': '228.0800',
#    '2. high': '258.6800',
#    '3. low': '212.6100',
#    '4. close': '247.7400',
#    '5. volume': '346165813'},
#   '2020-03-20': {'1. open': '241.9500',
#    '2. high': '259.0800',
#    '3. low': '228.0000',
#    '4. close': '229.2400',
#    '5. volume': '405065837'},
#   '2020-03-13': {'1. open': '263.7500',
#    '2. high': '286.4400',
#    '3. low': '248.0000',
#    '4. close': '277.9700',
#    '5. volume': '404405247'},
#   '2020-03-06': {'1. open': '282.2800',
#    '2. high': '304.0000',
#    '3. low': '277.7200',
#    '4. close': '289.0300',
#    '5. volume': '323450224'},
#   '2020-02-28': {'1. open': '297.2600',
#    '2. high': '304.1800',
#    '3. low': '256.3700',
#    '4. close': '273.3600',
#    '5. volume': '349768234'},
#   '2020-02-21': {'1. open': '315.3600',
#    '2. high': '324.6500',
#    '3. low': '310.5000',
#    '4. close': '313.0500',
#    '5. volume': '119254440'},
#   '2020-02-14': {'1. open': '314.1800',
#    '2. high': '327.2200',
#    '3. low': '313.8500',
#    '4. close': '324.9500',
#    '5. volume': '123065907'},
#   '2020-02-07': {'1. open': '304.3000',
#    '2. high': '325.2200',
#    '3. low': '302.2200',
#    '4. close': '320.0300',
#    '5. volume': '163134650'},
#   '2020-01-31': {'1. open': '310.0600',
#    '2. high': '327.8500',
#    '3. low': '304.8800',
#    '4. close': '309.5100',
#    '5. volume': '216776323'},
#   '2020-01-24': {'1. open': '317.1900',
#    '2. high': '323.3300',
#    '3. low': '315.6500',
#    '4. close': '318.3100',
#    '5. volume': '115445527'},
#   '2020-01-17': {'1. open': '311.6400',
#    '2. high': '318.7400',
#    '3. low': '309.5500',
#    '4. close': '318.7300',
#    '5. volume': '162824452'},
#   '2020-01-10': {'1. open': '293.7900',
#    '2. high': '312.6700',
#    '3. low': '292.7500',
#    '4. close': '310.3300',
#    '5. volume': '168452059'},
#   '2020-01-03': {'1. open': '289.4600',
#    '2. high': '300.6000',
#    '3. low': '285.2200',
#    '4. close': '297.4300',
#    '5. volume': '131852981'},
#   '2019-12-27': {'1. open': '280.5300',
#    '2. high': '293.9700',
#    '3. low': '280.3700',
#    '4. close': '289.8000',
#    '5. volume': '96724537'},
#   '2019-12-20': {'1. open': '277.0000',
#    '2. high': '282.6500',
#    '3. low': '276.9800',
#    '4. close': '279.4400',
#    '5. volume': '183341280'},
#   '2019-12-13': {'1. open': '270.0000',
#    '2. high': '275.3000',
#    '3. low': '264.9100',
#    '4. close': '275.1500',
#    '5. volume': '142408267'},
#   '2019-12-06': {'1. open': '267.2700',
#    '2. high': '271.0000',
#    '3. low': '256.2900',
#    '4. close': '270.7100',
#    '5. volume': '115090042'},
#   '2019-11-29': {'1. open': '262.7100',
#    '2. high': '268.0000',
#    '3. low': '262.5000',
#    '4. close': '267.2500',
#    '5. volume': '75404884'},
#   '2019-11-22': {'1. open': '265.8000',
#    '2. high': '268.0000',
#    '3. low': '260.4000',
#    '4. close': '261.7800',
#    '5. volume': '114060454'},
#   '2019-11-15': {'1. open': '258.3000',
#    '2. high': '265.7800',
#    '3. low': '258.2800',
#    '4. close': '265.7600',
#    '5. volume': '115661500'},
#   '2019-11-08': {'1. open': '257.3300',
#    '2. high': '260.4400',
#    '3. low': '255.3700',
#    '4. close': '260.1400',
#    '5. volume': '106014081'},
#   '2019-11-01': {'1. open': '247.4200',
#    '2. high': '255.9300',
#    '3. low': '237.2600',
#    '4. close': '255.8200',
#    '5. volume': '163067611'},
#   '2019-10-25': {'1. open': '237.5200',
#    '2. high': '246.7300',
#    '3. low': '237.3200',
#    '4. close': '246.5800',
#    '5. volume': '100713664'},
#   '2019-10-18': {'1. open': '234.9000',
#    '2. high': '238.1300',
#    '3. low': '233.2000',
#    '4. close': '236.4100',
#    '5. volume': '108261581'},
#   '2019-10-11': {'1. open': '226.2700',
#    '2. high': '237.6400',
#    '3. low': '224.3300',
#    '4. close': '236.2100',
#    '5. volume': '150154587'},
#   '2019-10-04': {'1. open': '220.9000',
#    '2. high': '228.2200',
#    '3. low': '215.1300',
#    '4. close': '227.0100',
#    '5. volume': '163381242'},
#   '2019-09-27': {'1. open': '218.9500',
#    '2. high': '222.4900',
#    '3. low': '217.1400',
#    '4. close': '218.8200',
#    '5. volume': '117784618'},
#   '2019-09-20': {'1. open': '217.7300',
#    '2. high': '223.7600',
#    '3. low': '217.4700',
#    '4. close': '217.7300',
#    '5. volume': '145352672'},
#   '2019-09-13': {'1. open': '214.8400',
#    '2. high': '226.4200',
#    '3. low': '211.0700',
#    '4. close': '218.7500',
#    '5. volume': '175366943'},
#   '2019-09-06': {'1. open': '206.4300',
#    '2. high': '214.4200',
#    '3. low': '204.2200',
#    '4. close': '213.2600',
#    '5. volume': '82585672'},
#   '2019-08-30': {'1. open': '205.8600',
#    '2. high': '210.4500',
#    '3. low': '203.3200',
#    '4. close': '208.7400',
#    '5. volume': '110091319'},
#   '2019-08-23': {'1. open': '210.6200',
#    '2. high': '214.4400',
#    '3. low': '201.0000',
#    '4. close': '202.6400',
#    '5. volume': '142066853'},
#   '2019-08-16': {'1. open': '199.6200',
#    '2. high': '212.1400',
#    '3. low': '199.1500',
#    '4. close': '206.5000',
#    '5. volume': '163266105'},
#   '2019-08-09': {'1. open': '197.9900',
#    '2. high': '203.5300',
#    '3. low': '192.5800',
#    '4. close': '200.9900',
#    '5. volume': '173211425'},
#   '2019-08-02': {'1. open': '208.4600',
#    '2. high': '221.3700',
#    '3. low': '201.6300',
#    '4. close': '204.0200',
#    '5. volume': '219770512'},
#   '2019-07-26': {'1. open': '203.6500',
#    '2. high': '209.7300',
#    '3. low': '203.6100',
#    '4. close': '207.7400',
#    '5. volume': '87153118'},
#   '2019-07-19': {'1. open': '204.0900',
#    '2. high': '206.5000',
#    '3. low': '202.3600',
#    '4. close': '202.5900',
#    '5. volume': '87433154'},
#   '2019-07-12': {'1. open': '200.8100',
#    '2. high': '204.3900',
#    '3. low': '198.4100',
#    '4. close': '203.3000',
#    '5. volume': '101600835'},
#   '2019-07-05': {'1. open': '203.1700',
#    '2. high': '205.0800',
#    '3. low': '200.6500',
#    '4. close': '204.2300',
#    '5. volume': '72879519'},
#   '2019-06-28': {'1. open': '198.5400',
#    '2. high': '201.5700',
#    '3. low': '195.2900',
#    '4. close': '197.9200',
#    '5. volume': '117368626'},
#   '2019-06-21': {'1. open': '192.9000',
#    '2. high': '200.8500',
#    '3. low': '192.1700',
#    '4. close': '198.7800',
#    '5. volume': '131658960'},
#   '2019-06-14': {'1. open': '191.8100',
#    '2. high': '196.7900',
#    '3. low': '190.3000',
#    '4. close': '192.7400',
#    '5. volume': '111843021'},
#   '2019-06-07': {'1. open': '175.6000',
#    '2. high': '191.9200',
#    '3. low': '170.2700',
#    '4. close': '190.1500',
#    '5. volume': '154348161'},
#   '2019-05-31': {'1. open': '178.9200',
#    '2. high': '180.5900',
#    '3. low': '174.9900',
#    '4. close': '175.0700',
#    '5. volume': '104691321'},
#   '2019-05-24': {'1. open': '183.5200',
#    '2. high': '188.0000',
#    '3. low': '177.8100',
#    '4. close': '178.9700',
#    '5. volume': '156970116'},
#   '2019-05-17': {'1. open': '187.7100',
#    '2. high': '192.4700',
#    '3. low': '182.8500',
#    '4. close': '189.0000',
#    '5. volume': '186415472'},
#   '2019-05-10': {'1. open': '204.2900',
#    '2. high': '208.8400',
#    '3. low': '192.7700',
#    '4. close': '197.1800',
#    '5. volume': '173663634'},
#   '2019-05-03': {'1. open': '204.4000',
#    '2. high': '215.3100',
#    '3. low': '199.1100',
#    '4. close': '211.7500',
#    '5. volume': '186455669'},
#   '2019-04-26': {'1. open': '202.8300',
#    '2. high': '208.4800',
#    '3. low': '202.1200',
#    '4. close': '204.3000',
#    '5. volume': '97495453'},
#   '2019-04-18': {'1. open': '198.5800',
#    '2. high': '204.1500',
#    '3. low': '198.0100',
#    '4. close': '203.8600',
#    '5. volume': '96335577'},
#   '2019-04-12': {'1. open': '196.4200',
#    '2. high': '202.8500',
#    '3. low': '196.2100',
#    '4. close': '198.8700',
#    '5. volume': '132006698'},
#   '2019-04-05': {'1. open': '191.6400',
#    '2. high': '197.1000',
#    '3. low': '188.3800',
#    '4. close': '197.0000',
#    '5. volume': '111540445'},
#   '2019-03-29': {'1. open': '191.5100',
#    '2. high': '192.8800',
#    '3. low': '184.5800',
#    '4. close': '189.9500',
#    '5. volume': '167838582'},
#   '2019-03-22': {'1. open': '185.8000',
#    '2. high': '197.6900',
#    '3. low': '184.7300',
#    '4. close': '191.0500',
#    '5. volume': '182343335'},
#   '2019-03-15': {'1. open': '175.4900',
#    '2. high': '187.3300',
#    '3. low': '175.3500',
#    '4. close': '186.1200',
#    '5. volume': '158133562'},
#   '2019-03-08': {'1. open': '175.6900',
#    '2. high': '177.7500',
#    '3. low': '169.5000',
#    '4. close': '172.9100',
#    '5. volume': '116779738'},
#   '2019-03-01': {'1. open': '174.1600',
#    '2. high': '175.8700',
#    '3. low': '172.7300',
#    '4. close': '174.9700',
#    '5. volume': '120880541'},
#   '2019-02-22': {'1. open': '169.7100',
#    '2. high': '173.3200',
#    '3. low': '169.4900',
#    '4. close': '172.9700',
#    '5. volume': '81250012'},
#   '2019-02-15': {'1. open': '171.0500',
#    '2. high': '172.4800',
#    '3. low': '169.2500',
#    '4. close': '170.4200',
#    '5. volume': '112229742'},
#   '2019-02-08': {'1. open': '167.4100',
#    '2. high': '175.5700',
#    '3. low': '167.2800',
#    '4. close': '170.4100',
#    '5. volume': '151398457'},
#   '2019-02-01': {'1. open': '155.7900',
#    '2. high': '169.0000',
#    '3. low': '153.6600',
#    '4. close': '166.5200',
#    '5. volume': '202296864'},
#   '2019-01-25': {'1. open': '156.4100',
#    '2. high': '158.1300',
#    '3. low': '151.7000',
#    '4. close': '157.7600',
#    '5. volume': '112513982'},
#   '2019-01-18': {'1. open': '150.8500',
#    '2. high': '157.8800',
#    '3. low': '149.2200',
#    '4. close': '156.8200',
#    '5. volume': '155291399'},
#   '2019-01-11': {'1. open': '148.7000',
#    '2. high': '154.5300',
#    '3. low': '145.9000',
#    '4. close': '152.2900',
#    '5. volume': '203706070'},
#   '2019-01-04': {'1. open': '158.5300',
#    '2. high': '159.3600',
#    '3. low': '142.0000',
#    '4. close': '148.2600',
#    '5. volume': '221962468'},
#   '2018-12-28': {'1. open': '148.1500',
#    '2. high': '158.5200',
#    '3. low': '146.5900',
#    '4. close': '156.2300',
#    '5. volume': '191160265'},
#   '2018-12-21': {'1. open': '165.4500',
#    '2. high': '168.3500',
#    '3. low': '149.6300',
#    '4. close': '150.7300',
#    '5. volume': '287694081'},
#   '2018-12-14': {'1. open': '165.0000',
#    '2. high': '172.5700',
#    '3. low': '163.3300',
#    '4. close': '165.4800',
#    '5. volume': '217536870'},
#   '2018-12-07': {'1. open': '184.4600',
#    '2. high': '184.9400',
#    '3. low': '168.3000',
#    '4. close': '168.4900',
#    '5. volume': '167522325'},
#   '2018-11-30': {'1. open': '174.2400',
#    '2. high': '182.8000',
#    '3. low': '170.2600',
#    '4. close': '178.5800',
#    '5. volume': '213749977'},
#   '2018-11-23': {'1. open': '190.0000',
#    '2. high': '190.7000',
#    '3. low': '172.1000',
#    '4. close': '172.2900',
#    '5. volume': '164494301'},
#   '2018-11-16': {'1. open': '199.0000',
#    '2. high': '199.8500',
#    '3. low': '185.9300',
#    '4. close': '193.5300',
#    '5. volume': '242226465'},
#   '2018-11-09': {'1. open': '204.3000',
#    '2. high': '210.1200',
#    '3. low': '198.1700',
#    '4. close': '204.4700',
#    '5. volume': '191199370'},
#   '2018-11-02': {'1. open': '219.1900',
#    '2. high': '222.3600',
#    '3. low': '205.4300',
#    '4. close': '207.4800',
#    '5. volume': '270606277'},
#   '2018-10-26': {'1. open': '219.7900',
#    '2. high': '224.2300',
#    '3. low': '212.6700',
#    '4. close': '216.3000',
#    '5. volume': '185599234'},
#   '2018-10-19': {'1. open': '221.1600',
#    '2. high': '222.9900',
#    '3. low': '213.0000',
#    '4. close': '219.3100',
#    '5. volume': '148520408'},
#   '2018-10-12': {'1. open': '222.2100',
#    '2. high': '227.2700',
#    '3. low': '212.3200',
#    '4. close': '222.1100',
#    '5. volume': '192007749'},
#   '2018-10-05': {'1. open': '227.9500',
#    '2. high': '233.4700',
#    '3. low': '220.5800',
#    '4. close': '224.2900',
#    '5. volume': '142666234'},
#   '2018-09-28': {'1. open': '216.8200',
#    '2. high': '226.4400',
#    '3. low': '216.6300',
#    '4. close': '225.7400',
#    '5. volume': '129343034'},
#   '2018-09-21': {'1. open': '222.1500',
#    '2. high': '222.9500',
#    '3. low': '215.3000',
#    '4. close': '217.6600',
#    '5. volume': '218746220'},
#   '2018-09-14': {'1. open': '220.9500',
#    '2. high': '228.3500',
#    '3. low': '216.4700',
#    '4. close': '223.8400',
#    '5. volume': '198249908'},
#   '2018-09-07': {'1. open': '228.4100',
#    '2. high': '229.6700',
#    '3. low': '220.7100',
#    '4. close': '221.3000',
#    '5. volume': '132632878'},
#   '2018-08-31': {'1. open': '217.1500',
#    '2. high': '228.8700',
#    '3. low': '216.3300',
#    '4. close': '227.6300',
#    '5. volume': '162690645'},
#   '2018-08-24': {'1. open': '218.1000',
#    '2. high': '219.1800',
#    '3. low': '213.8400',
#    '4. close': '216.1600',
#    '5. volume': '112825161'},
#   '2018-08-17': {'1. open': '207.7000',
#    '2. high': '217.9500',
#    '3. low': '207.7000',
#    '4. close': '217.5800',
#    '5. volume': '139373818'},
#   '2018-08-10': {'1. open': '208.0000',
#    '2. high': '209.7800',
#    '3. low': '204.5200',
#    '4. close': '207.5300',
#    '5. volume': '121642089'},
#   '2018-08-03': {'1. open': '191.9000',
#    '2. high': '208.7400',
#    '3. low': '189.0700',
#    '4. close': '207.9900',
#    '5. volume': '224189697'},
#   '2018-07-27': {'1. open': '190.6800',
#    '2. high': '195.9600',
#    '3. low': '189.5600',
#    '4. close': '190.9800',
#    '5. volume': '94613682'},
#   '2018-07-20': {'1. open': '191.5200',
#    '2. high': '192.6500',
#    '3. low': '189.2000',
#    '4. close': '191.4400',
#    '5. volume': '87963808'},
#   '2018-07-13': {'1. open': '189.5000',
#    '2. high': '191.8400',
#    '3. low': '187.6100',
#    '4. close': '191.3300',
#    '5. volume': '85088176'},
#   '2018-07-06': {'1. open': '183.8200',
#    '2. high': '188.4300',
#    '3. low': '183.4200',
#    '4. close': '187.9700',
#    '5. volume': '65775642'},
#   '2018-06-29': {'1. open': '183.4000',
#    '2. high': '187.2800',
#    '3. low': '180.7300',
#    '4. close': '185.1100',
#    '5. volume': '121620526'},
#   '2018-06-22': {'1. open': '187.8800',
#    '2. high': '189.2200',
#    '3. low': '183.4500',
#    '4. close': '184.9200',
#    '5. volume': '125604366'},
#   '2018-06-15': {'1. open': '191.3500',
#    '2. high': '192.8800',
#    '3. low': '188.2600',
#    '4. close': '188.8400',
#    '5. volume': '140187228'},
#   '2018-06-08': {'1. open': '191.6400',
#    '2. high': '194.2000',
#    '3. low': '189.7700',
#    '4. close': '191.7000',
#    '5. volume': '116769735'},
#   '2018-06-01': {'1. open': '187.6000',
#    '2. high': '190.2600',
#    '3. low': '186.1400',
#    '4. close': '190.2400',
#    '5. volume': '92129925'},
#   '2018-05-25': {'1. open': '188.0000',
#    '2. high': '189.6500',
#    '3. low': '185.7600',
#    '4. close': '188.5800',
#    '5. volume': '94394844'},
#   '2018-05-18': {'1. open': '189.0100',
#    '2. high': '189.5300',
#    '3. low': '185.1000',
#    '4. close': '186.3100',
#    '5. volume': '99248752'},
#   '2018-05-11': {'1. open': '185.1800',
#    '2. high': '190.3700',
#    '3. low': '183.6700',
#    '4. close': '188.5900',
#    '5. volume': '148266951'},
#   '2018-05-04': {'1. open': '162.1300',
#    '2. high': '184.2500',
#    '3. low': '161.8400',
#    '4. close': '183.8300',
#    '5. volume': '252805668'},
#   '2018-04-27': {'1. open': '166.8300',
#    '2. high': '166.9200',
#    '3. low': '160.6300',
#    '4. close': '162.3200',
#    '5. volume': '162208431'},
#   '2018-04-20': {'1. open': '175.0300',
#    '2. high': '178.9400',
#    '3. low': '165.4300',
#    '4. close': '165.7200',
#    '5. volume': '169238340'},
#   '2018-04-13': {'1. open': '169.8800',
#    '2. high': '175.8400',
#    '3. low': '169.8500',
#    '4. close': '174.7300',
#    '5. volume': '128077139'},
#   '2018-04-06': {'1. open': '166.6400',
#    '2. high': '174.2300',
#    '3. low': '164.4700',
#    '4. close': '168.3800',
#    '5. volume': '164408813'},
#   '2018-03-29': {'1. open': '168.0700',
#    '2. high': '175.1500',
#    '3. low': '165.1900',
#    '4. close': '167.7800',
#    '5. volume': '155302506'},
#   '2018-03-23': {'1. open': '177.3200',
#    '2. high': '177.4700',
#    '3. low': '164.9400',
#    '4. close': '164.9400',
#    '5. volume': '168666122'},
#   '2018-03-16': {'1. open': '180.2900',
#    '2. high': '183.5000',
#    '3. low': '177.6200',
#    '4. close': '178.0200',
#    '5. volume': '151720299'},
#   '2018-03-09': {'1. open': '175.2100',
#    '2. high': '180.0000',
#    '3. low': '174.2700',
#    '4. close': '179.9800',
#    '5. volume': '138442235'},
#   '2018-03-02': {'1. open': '176.3500',
#    '2. high': '180.6200',
#    '3. low': '172.4500',
#    '4. close': '176.2100',
#    '5. volume': '196432091'},
#   '2018-02-23': {'1. open': '172.0500',
#    '2. high': '175.6500',
#    '3. low': '171.0100',
#    '4. close': '175.5000',
#    '5. volume': '133197874'},
#   '2018-02-16': {'1. open': '158.5000',
#    '2. high': '174.8200',
#    '3. low': '157.5100',
#    '4. close': '172.4300',
#    '5. volume': '222582467'},
#   '2018-02-09': {'1. open': '159.1000',
#    '2. high': '163.8800',
#    '3. low': '150.2400',
#    '4. close': '156.4100',
#    '5. volume': '299885932'},
#   '2018-02-02': {'1. open': '170.1600',
#    '2. high': '170.1600',
#    '3. low': '160.1000',
#    '4. close': '160.5000',
#    '5. volume': '248091289'},
#   '2018-01-26': {'1. open': '177.3000',
#    '2. high': '179.4400',
#    '3. low': '170.0600',
#    '4. close': '171.5100',
#    '5. volume': '185072080'},
#   '2018-01-19': {'1. open': '177.9000',
#    '2. high': '180.1000',
#    '3. low': '175.0700',
#    '4. close': '178.4600',
#    '5. volume': '122974060'},
#   '2018-01-12': {'1. open': '174.3500',
#    '2. high': '177.3600',
#    '3. low': '173.0000',
#    '4. close': '177.0900',
#    '5. volume': '107548622'},
#   '2018-01-05': {'1. open': '170.1600',
#    '2. high': '175.3700',
#    '3. low': '169.2600',
#    '4. close': '175.0000',
#    '5. volume': '99095223'},
#   '2017-12-29': {'1. open': '170.8000',
#    '2. high': '171.8500',
#    '3. low': '169.2200',
#    '4. close': '169.2300',
#    '5. volume': '96281679'},
#   '2017-12-22': {'1. open': '174.8800',
#    '2. high': '177.2000',
#    '3. low': '173.2500',
#    '4. close': '175.0100',
#    '5. volume': '115320238'},
#   '2017-12-15': {'1. open': '169.2000',
#    '2. high': '174.1700',
#    '3. low': '168.7900',
#    '4. close': '173.9700',
#    '5. volume': '132453689'},
#   '2017-12-08': {'1. open': '172.4800',
#    '2. high': '172.6200',
#    '3. low': '166.4600',
#    '4. close': '169.3700',
#    '5. volume': '134914322'},
#   '2017-12-01': {'1. open': '175.0500',
#    '2. high': '175.0800',
#    '3. low': '167.1600',
#    '4. close': '171.0500',
#    '5. volume': '166555527'},
#   '2017-11-24': {'1. open': '170.2900',
#    '2. high': '175.5000',
#    '3. low': '169.5600',
#    '4. close': '174.9700',
#    '5. volume': '79873651'},
#   '2017-11-17': {'1. open': '173.5000',
#    '2. high': '174.5000',
#    '3. low': '168.3800',
#    '4. close': '170.1500',
#    '5. volume': '114281964'},
#   '2017-11-10': {'1. open': '172.3650',
#    '2. high': '176.2400',
#    '3. low': '171.7200',
#    '4. close': '174.6700',
#    '5. volume': '135758833'},
#   '2017-11-03': {'1. open': '163.8900',
#    '2. high': '174.2600',
#    '3. low': '163.7200',
#    '4. close': '172.5000',
#    '5. volume': '203892677'},
#   '2017-10-27': {'1. open': '156.8900',
#    '2. high': '163.6000',
#    '3. low': '155.2700',
#    '4. close': '163.0500',
#    '5. volume': '119574587'},
#   '2017-10-20': {'1. open': '157.9000',
#    '2. high': '160.8700',
#    '3. low': '155.0200',
#    '4. close': '156.2500',
#    '5. volume': '124593299'},
#   '2017-10-13': {'1. open': '155.8100',
#    '2. high': '158.0000',
#    '3. low': '155.1000',
#    '4. close': '156.9900',
#    '5. volume': '80597481'},
#   '2017-10-06': {'1. open': '154.2600',
#    '2. high': '155.4900',
#    '3. low': '152.4600',
#    '4. close': '155.3000',
#    '5. volume': '91971974'},
#   '2017-09-29': {'1. open': '149.9900',
#    '2. high': '154.7189',
#    '3. low': '149.1600',
#    '4. close': '154.1200',
#    '5. volume': '152105993'},
#   '2017-09-22': {'1. open': '160.1100',
#    '2. high': '160.5000',
#    '3. low': '150.5600',
#    '4. close': '151.8900',
#    '5. volume': '182738115'},
#   '2017-09-15': {'1. open': '160.5000',
#    '2. high': '163.9600',
#    '3. low': '157.9100',
#    '4. close': '159.8800',
#    '5. volume': '217839085'},
#   '2017-09-08': {'1. open': '163.7500',
#    '2. high': '164.2500',
#    '3. low': '158.5300',
#    '4. close': '158.6300',
#    '5. volume': '100402255'},
#   '2017-09-01': {'1. open': '160.1400',
#    '2. high': '164.9400',
#    '3. low': '159.9300',
#    '4. close': '164.0500',
#    '5. volume': '124482489'},
#   '2017-08-25': {'1. open': '157.5000',
#    '2. high': '160.7400',
#    '3. low': '155.1101',
#    '4. close': '159.8600',
#    '5. volume': '110686493'},
#   '2017-08-18': {'1. open': '159.3200',
#    '2. high': '162.5100',
#    '3. low': '156.7200',
#    '4. close': '157.5000',
#    '5. volume': '130951564'},
#   '2017-08-11': {'1. open': '157.0600',
#    '2. high': '161.8300',
#    '3. low': '154.6300',
#    '4. close': '157.4800',
#    '5. volume': '148310594'},
#   '2017-08-04': {'1. open': '149.9000',
#    '2. high': '159.7500',
#    '3. low': '148.1300',
#    '4. close': '156.3900',
#    '5. volume': '159721244'},
#   '2017-07-28': {'1. open': '150.5800',
#    '2. high': '153.9900',
#    '3. low': '147.3000',
#    '4. close': '149.5000',
#    '5. volume': '103916337'},
#   '2017-07-21': {'1. open': '148.8200',
#    '2. high': '151.7400',
#    '3. low': '148.5700',
#    '4. close': '150.2700',
#    '5. volume': '103297255'},
#   '2017-07-14': {'1. open': '144.1100',
#    '2. high': '149.3300',
#    '3. low': '143.3700',
#    '4. close': '149.0400',
#    '5. volume': '107844162'},
#   '2017-07-07': {'1. open': '144.8800',
#    '2. high': '145.3000',
#    '3. low': '142.4100',
#    '4. close': '144.1800',
#    '5. volume': '76896820'},
#   '2017-06-30': {'1. open': '147.1700',
#    '2. high': '148.2800',
#    '3. low': '142.2800',
#    '4. close': '144.0200',
#    '5. volume': '125310202'},
#   '2017-06-23': {'1. open': '143.6600',
#    '2. high': '147.1600',
#    '3. low': '143.6600',
#    '4. close': '146.2800',
#    '5. volume': '121757322'},
#   '2017-06-16': {'1. open': '145.7400',
#    '2. high': '147.5000',
#    '3. low': '142.2000',
#    '4. close': '142.2700',
#    '5. volume': '217066551'},
#   '2017-06-09': {'1. open': '154.3400',
#    '2. high': '155.9800',
#    '3. low': '146.0200',
#    '4. close': '148.9800',
#    '5. volume': '157386327'},
#   '2017-06-02': {'1. open': '153.4200',
#    '2. high': '155.4500',
#    '3. low': '152.2200',
#    '4. close': '155.4500',
#    '5. volume': '86663811'},
#   '2017-05-26': {'1. open': '154.0000',
#    '2. high': '154.9000',
#    '3. low': '152.6700',
#    '4. close': '153.6100',
#    '5. volume': '101565411'},
#   '2017-05-19': {'1. open': '156.0100',
#    '2. high': '156.6500',
#    '3. low': '149.7100',
#    '4. close': '153.0600',
#    '5. volume': '154981942'},
#   '2017-05-12': {'1. open': '149.0300',
#    '2. high': '156.4200',
#    '3. low': '149.0300',
#    '4. close': '156.1000',
#    '5. volume': '167770544'},
#   '2017-05-05': {'1. open': '145.1000',
#    '2. high': '148.9800',
#    '3. low': '144.2700',
#    '4. close': '148.9600',
#    '5. volume': '167777285'},
#   '2017-04-28': {'1. open': '143.5000',
#    '2. high': '144.9000',
#    '3. low': '143.1800',
#    '4. close': '143.6500',
#    '5. volume': '89143525'},
#   '2017-04-21': {'1. open': '141.4800',
#    '2. high': '142.9200',
#    '3. low': '140.4500',
#    '4. close': '142.2700',
#    '5. volume': '89248503'},
#   '2017-04-13': {'1. open': '143.6000',
#    '2. high': '143.8792',
#    '3. low': '140.0600',
#    '4. close': '141.0500',
#    '5. volume': '87485653'},
#   '2017-04-07': {'1. open': '143.7100',
#    '2. high': '145.4600',
#    '3. low': '143.0500',
#    '4. close': '143.3400',
#    '5. volume': '105402499'},
#   '2017-03-31': {'1. open': '139.3900',
#    '2. high': '144.5000',
#    '3. low': '138.6200',
#    '4. close': '143.6600',
#    '5. volume': '127008757'},
#   '2017-03-24': {'1. open': '140.4000',
#    '2. high': '142.8000',
#    '3. low': '139.7300',
#    '4. close': '140.6400',
#    '5. volume': '129673979'},
#   '2017-03-17': {'1. open': '138.8500',
#    '2. high': '141.0200',
#    '3. low': '138.8200',
#    '4. close': '139.9900',
#    '5. volume': '121539506'},
#   '2017-03-10': {'1. open': '139.3650',
#    '2. high': '139.9800',
#    '3. low': '137.0500',
#    '4. close': '139.1400',
#    '5. volume': '99672282'},
#   '2017-03-03': {'1. open': '137.1400',
#    '2. high': '140.2786',
#    '3. low': '136.2800',
#    '4. close': '139.7800',
#    '5. volume': '127936976'},
#   '2017-02-24': {'1. open': '136.2300',
#    '2. high': '137.4800',
#    '3. low': '135.2800',
#    '4. close': '136.6600',
#    '5. volume': '87908859'},
#   '2017-02-17': {'1. open': '133.0800',
#    '2. high': '136.2700',
#    '3. low': '132.7500',
#    '4. close': '135.7200',
#    '5. volume': '136667496'},
#   '2017-02-10': {'1. open': '129.1300',
#    '2. high': '132.9400',
#    '3. low': '128.9000',
#    '4. close': '132.1200',
#    '5. volume': '136449154'},
#   '2017-02-03': {'1. open': '120.9300',
#    '2. high': '130.4900',
# ...
#    '5. volume': '292504700'},
#   '2006-03-31': {'1. open': '60.2300',
#    '2. high': '63.6100',
#    '3. low': '57.6700',
#    '4. close': '62.7200',
#    '5. volume': '251115600'},
#   '2006-03-24': {'1. open': '65.2100',
#    '2. high': '65.4600',
#    '3. low': '59.0300',
#    '4. close': '59.9600',
#    '5. volume': '207018200'},
#   '2006-03-17': {'1. open': '65.6100',
#    '2. high': '68.0400',
#    '3. low': '64.1100',
#    '4. close': '64.6600',
#    '5. volume': '141317300'},
#   '2006-03-10': {'1. open': '67.6000',
#    '2. high': '67.7200',
#    '3. low': '62.4500',
#    '4. close': '63.1900',
#    '5. volume': '152901500'},
#   '2006-03-03': {'1. open': '72.0200',
#    '2. high': '72.4000',
#    '3. low': '67.5300',
#    '4. close': '67.7200',
#    '5. volume': '149463600'},
#   '2006-02-24': {'1. open': '70.6300',
#    '2. high': '73.0000',
#    '3. low': '68.0000',
#    '4. close': '71.4600',
#    '5. volume': '112482400'},
#   '2006-02-17': {'1. open': '66.5200',
#    '2. high': '71.0100',
#    '3. low': '64.6400',
#    '4. close': '70.2900',
#    '5. volume': '168870800'},
#   '2006-02-10': {'1. open': '72.1600',
#    '2. high': '72.5100',
#    '3. low': '62.9000',
#    '4. close': '67.3100',
#    '5. volume': '246569800'},
#   '2006-02-03': {'1. open': '71.2800',
#    '2. high': '76.6000',
#    '3. low': '70.8700',
#    '4. close': '71.8470',
#    '5. volume': '151163400'},
#   '2006-01-27': {'1. open': '76.1000',
#    '2. high': '79.5600',
#    '3. low': '71.1000',
#    '4. close': '72.0300',
#    '5. volume': '200465100'},
#   '2006-01-20': {'1. open': '85.7000',
#    '2. high': '86.3800',
#    '3. low': '75.8300',
#    '4. close': '76.0890',
#    '5. volume': '173816700'},
#   '2006-01-13': {'1. open': '76.7300',
#    '2. high': '86.4000',
#    '3. low': '75.7400',
#    '4. close': '85.5899',
#    '5. volume': '232350700'},
#   '2006-01-06': {'1. open': '72.3320',
#    '2. high': '76.7000',
#    '3. low': '72.2500',
#    '4. close': '76.3000',
#    '5. volume': '92168500'},
#   '2005-12-30': {'1. open': '74.0000',
#    '2. high': '75.1800',
#    '3. low': '70.3400',
#    '4. close': '71.8900',
#    '5. volume': '75106900'},
#   '2005-12-23': {'1. open': '71.1100',
#    '2. high': '74.4900',
#    '3. low': '71.0400',
#    '4. close': '73.3500',
#    '5. volume': '74450300'},
#   '2005-12-16': {'1. open': '74.8700',
#    '2. high': '75.4600',
#    '3. low': '70.2700',
#    '4. close': '71.1100',
#    '5. volume': '132209300'},
#   '2005-12-09': {'1. open': '71.9500',
#    '2. high': '74.8300',
#    '3. low': '71.4900',
#    '4. close': '74.3305',
#    '5. volume': '123787400'},
#   '2005-12-02': {'1. open': '70.7200',
#    '2. high': '72.7400',
#    '3. low': '67.3500',
#    '4. close': '72.6300',
#    '5. volume': '150510100'},
#   '2005-11-25': {'1. open': '64.8200',
#    '2. high': '69.5400',
#    '3. low': '63.7200',
#    '4. close': '69.3400',
#    '5. volume': '69030700'},
#   '2005-11-18': {'1. open': '61.5400',
#    '2. high': '65.8800',
#    '3. low': '60.9100',
#    '4. close': '64.5600',
#    '5. volume': '103302000'},
#   '2005-11-11': {'1. open': '60.8500',
#    '2. high': '62.1100',
#    '3. low': '59.0100',
#    '4. close': '61.5400',
#    '5. volume': '98440000'},
#   '2005-11-04': {'1. open': '55.2000',
#    '2. high': '62.3200',
#    '3. low': '54.7500',
#    '4. close': '61.1500',
#    '5. volume': '153928900'},
#   '2005-10-28': {'1. open': '55.2500',
#    '2. high': '57.5600',
#    '3. low': '54.1700',
#    '4. close': '54.4700',
#    '5. volume': '103135800'},
#   '2005-10-21': {'1. open': '53.9800',
#    '2. high': '56.9800',
#    '3. low': '51.2100',
#    '4. close': '55.6600',
#    '5. volume': '156771200'},
#   '2005-10-14': {'1. open': '51.8400',
#    '2. high': '54.3500',
#    '3. low': '47.8700',
#    '4. close': '54.0000',
#    '5. volume': '261857300'},
#   '2005-10-07': {'1. open': '54.1600',
#    '2. high': '55.3500',
#    '3. low': '50.5500',
#    '4. close': '51.3000',
#    '5. volume': '110471500'},
#   '2005-09-30': {'1. open': '54.0300',
#    '2. high': '54.5600',
#    '3. low': '50.5900',
#    '4. close': '53.6100',
#    '5. volume': '113653200'},
#   '2005-09-23': {'1. open': '51.0500',
#    '2. high': '53.8100',
#    '3. low': '51.0500',
#    '4. close': '53.2000',
#    '5. volume': '109303300'},
#   '2005-09-16': {'1. open': '51.1000',
#    '2. high': '51.6300',
#    '3. low': '49.3300',
#    '4. close': '51.2100',
#    '5. volume': '86652400'},
#   '2005-09-09': {'1. open': '46.6900',
#    '2. high': '51.3500',
#    '3. low': '46.5500',
#    '4. close': '51.3100',
#    '5. volume': '110713400'},
#   '2005-09-02': {'1. open': '45.2700',
#    '2. high': '47.1700',
#    '3. low': '45.2600',
#    '4. close': '46.2200',
#    '5. volume': '62741400'},
#   '2005-08-26': {'1. open': '46.1500',
#    '2. high': '47.1200',
#    '3. low': '45.2600',
#    '4. close': '45.7400',
#    '5. volume': '64025700'},
#   '2005-08-19': {'1. open': '46.4800',
#    '2. high': '48.3300',
#    '3. low': '45.7500',
#    '4. close': '45.8300',
#    '5. volume': '105114400'},
#   '2005-08-12': {'1. open': '43.0000',
#    '2. high': '46.2200',
#    '3. low': '42.6100',
#    '4. close': '46.1000',
#    '5. volume': '75221000'},
#   '2005-08-05': {'1. open': '42.6000',
#    '2. high': '43.5000',
#    '3. low': '42.0200',
#    '4. close': '42.9900',
#    '5. volume': '49310100'},
#   '2005-07-29': {'1. open': '43.9900',
#    '2. high': '44.3800',
#    '3. low': '42.2600',
#    '4. close': '42.6500',
#    '5. volume': '59298600'},
#   '2005-07-22': {'1. open': '41.4100',
#    '2. high': '44.0400',
#    '3. low': '41.0700',
#    '4. close': '44.0000',
#    '5. volume': '86290200'},
#   '2005-07-15': {'1. open': '38.3700',
#    '2. high': '42.0100',
#    '3. low': '37.7800',
#    '4. close': '41.5500',
#    '5. volume': '151585900'},
#   '2005-07-08': {'1. open': '36.6000',
#    '2. high': '38.2800',
#    '3. low': '36.5000',
#    '4. close': '38.2500',
#    '5. volume': '54405500'},
#   '2005-07-01': {'1. open': '36.8400',
#    '2. high': '38.1000',
#    '3. low': '36.1200',
#    '4. close': '36.5000',
#    '5. volume': '73829300'},
#   '2005-06-24': {'1. open': '37.8500',
#    '2. high': '39.7800',
#    '3. low': '37.3800',
#    '4. close': '37.7600',
#    '5. volume': '78719000'},
#   '2005-06-17': {'1. open': '35.8900',
#    '2. high': '38.5400',
#    '3. low': '35.7500',
#    '4. close': '38.3100',
#    '5. volume': '88955800'},
#   '2005-06-10': {'1. open': '38.3300',
#    '2. high': '38.6300',
#    '3. low': '35.5200',
#    '4. close': '35.8100',
#    '5. volume': '108229500'},
#   '2005-06-03': {'1. open': '40.6600',
#    '2. high': '40.7600',
#    '3. low': '37.7700',
#    '4. close': '38.2400',
#    '5. volume': '78173600'},
#   '2005-05-27': {'1. open': '37.8500',
#    '2. high': '40.9400',
#    '3. low': '37.8500',
#    '4. close': '40.5600',
#    '5. volume': '102627500'},
#   '2005-05-20': {'1. open': '34.5600',
#    '2. high': '37.6800',
#    '3. low': '34.5300',
#    '4. close': '37.5500',
#    '5. volume': '105184800'},
#   '2005-05-13': {'1. open': '37.2400',
#    '2. high': '37.4500',
#    '3. low': '33.1100',
#    '4. close': '34.7700',
#    '5. volume': '161103400'},
#   '2005-05-06': {'1. open': '36.2100',
#    '2. high': '37.3300',
#    '3. low': '36.0200',
#    '4. close': '37.2400',
#    '5. volume': '75873200'},
#   '2005-04-29': {'1. open': '36.4900',
#    '2. high': '37.5100',
#    '3. low': '35.2200',
#    '4. close': '36.0600',
#    '5. volume': '122056900'},
#   '2005-04-22': {'1. open': '35.0300',
#    '2. high': '37.7400',
#    '3. low': '34.0000',
#    '4. close': '35.5000',
#    '5. volume': '176881200'},
#   '2005-04-15': {'1. open': '44.2200',
#    '2. high': '44.2500',
#    '3. low': '35.2800',
#    '4. close': '35.3500',
#    '5. volume': '273426800'},
#   '2005-04-08': {'1. open': '40.9900',
#    '2. high': '44.4500',
#    '3. low': '40.1600',
#    '4. close': '43.7400',
#    '5. volume': '96714900'},
#   '2005-04-01': {'1. open': '42.7500',
#    '2. high': '42.9600',
#    '3. low': '40.5700',
#    '4. close': '40.8900',
#    '5. volume': '86040900'},
#   '2005-03-24': {'1. open': '43.2900',
#    '2. high': '43.9700',
#    '3. low': '42.0200',
#    '4. close': '42.5000',
#    '5. volume': '73395400'},
#   '2005-03-18': {'1. open': '40.5200',
#    '2. high': '43.4400',
#    '3. low': '39.5200',
#    '4. close': '42.9600',
#    '5. volume': '126924200'},
#   '2005-03-11': {'1. open': '42.8000',
#    '2. high': '43.2500',
#    '3. low': '38.8300',
#    '4. close': '40.2700',
#    '5. volume': '150160300'},
#   '2005-03-04': {'1. open': '44.6800',
#    '2. high': '45.1400',
#    '3. low': '41.2200',
#    '4. close': '42.8100',
#    '5. volume': '122158100'},
#   '2005-02-25': {'1. open': '86.3000',
#    '2. high': '89.9100',
#    '3. low': '85.2900',
#    '4. close': '88.9900',
#    '5. volume': '89268100'},
#   '2005-02-18': {'1. open': '83.1600',
#    '2. high': '90.8800',
#    '3. low': '82.0500',
#    '4. close': '86.8100',
#    '5. volume': '141154500'},
#   '2005-02-11': {'1. open': '78.9300',
#    '2. high': '81.9900',
#    '3. low': '76.6600',
#    '4. close': '81.2100',
#    '5. volume': '87500100'},
#   '2005-02-04': {'1. open': '74.5800',
#    '2. high': '79.9100',
#    '3. low': '74.5100',
#    '4. close': '78.8400',
#    '5. volume': '83477900'},
#   '2005-01-28': {'1. open': '70.9800',
#    '2. high': '73.9800',
#    '3. low': '70.5500',
#    '4. close': '73.9800',
#    '5. volume': '68717800'},
#   '2005-01-21': {'1. open': '69.7400',
#    '2. high': '71.6000',
#    '3. low': '69.2100',
#    '4. close': '70.4900',
#    '5. volume': '64010900'},
#   '2005-01-14': {'1. open': '69.9000',
#    '2. high': '74.4200',
#    '3. low': '63.3000',
#    '4. close': '70.2000',
#    '5. volume': '199858900'},
#   '2005-01-07': {'1. open': '64.7800',
#    '2. high': '69.6300',
#    '3. low': '62.6000',
#    '4. close': '69.2500',
#    '5. volume': '96468600'},
#   '2004-12-31': {'1. open': '64.6400',
#    '2. high': '65.1500',
#    '3. low': '62.0500',
#    '4. close': '64.4000',
#    '5. volume': '40084600'},
#   '2004-12-23': {'1. open': '65.4800',
#    '2. high': '66.0000',
#    '3. low': '61.6000',
#    '4. close': '64.0100',
#    '5. volume': '54362500'},
#   '2004-12-17': {'1. open': '65.7400',
#    '2. high': '67.5000',
#    '3. low': '64.6000',
#    '4. close': '64.9900',
#    '5. volume': '55691700'},
#   '2004-12-10': {'1. open': '64.3100',
#    '2. high': '66.7300',
#    '3. low': '62.0500',
#    '4. close': '65.1500',
#    '5. volume': '80607100'},
#   '2004-12-03': {'1. open': '69.0000',
#    '2. high': '69.5700',
#    '3. low': '61.7500',
#    '4. close': '62.6800',
#    '5. volume': '103005000'},
#   '2004-11-26': {'1. open': '58.0400',
#    '2. high': '65.7600',
#    '3. low': '57.9000',
#    '4. close': '64.5500',
#    '5. volume': '96796300'},
#   '2004-11-19': {'1. open': '55.0800',
#    '2. high': '56.9100',
#    '3. low': '54.2200',
#    '4. close': '55.1700',
#    '5. volume': '40952300'},
#   '2004-11-12': {'1. open': '54.5300',
#    '2. high': '55.6900',
#    '3. low': '53.3800',
#    '4. close': '55.5000',
#    '5. volume': '41327900'},
#   '2004-11-05': {'1. open': '52.5000',
#    '2. high': '56.1100',
#    '3. low': '52.0400',
#    '4. close': '54.7200',
#    '5. volume': '83390800'},
#   '2004-10-29': {'1. open': '47.1900',
#    '2. high': '53.2000',
#    '3. low': '46.9700',
#    '4. close': '52.4000',
#    '5. volume': '68839000'},
#   '2004-10-22': {'1. open': '44.7900',
#    '2. high': '48.3500',
#    '3. low': '44.7000',
#    '4. close': '47.4100',
#    '5. volume': '68132600'},
#   '2004-10-15': {'1. open': '38.8000',
#    '2. high': '45.7500',
#    '3. low': '37.6500',
#    '4. close': '45.5000',
#    '5. volume': '102618300'},
#   '2004-10-08': {'1. open': '39.0100',
#    '2. high': '40.9300',
#    '3. low': '38.4000',
#    '4. close': '39.0600',
#    '5. volume': '39498700'},
#   '2004-10-01': {'1. open': '36.9700',
#    '2. high': '39.2700',
#    '3. low': '36.8300',
#    '4. close': '38.6700',
#    '5. volume': '34189800'},
#   '2004-09-24': {'1. open': '36.9000',
#    '2. high': '38.8700',
#    '3. low': '36.8100',
#    '4. close': '37.2900',
#    '5. volume': '32147000'},
#   '2004-09-17': {'1. open': '35.8600',
#    '2. high': '37.3800',
#    '3. low': '34.7800',
#    '4. close': '37.1400',
#    '5. volume': '31673100'},
#   '2004-09-10': {'1. open': '35.4000',
#    '2. high': '36.5700',
#    '3. low': '35.2300',
#    '4. close': '35.8700',
#    '5. volume': '25622100'},
#   '2004-09-03': {'1. open': '34.0200',
#    '2. high': '35.9900',
#    '3. low': '33.9600',
#    '4. close': '35.2300',
#    '5. volume': '32325400'},
#   '2004-08-27': {'1. open': '30.8600',
#    '2. high': '35.1800',
#    '3. low': '30.6000',
#    '4. close': '34.3500',
#    '5. volume': '44269400'},
#   '2004-08-20': {'1. open': '30.8800',
#    '2. high': '31.8600',
#    '3. low': '30.3500',
#    '4. close': '30.8000',
#    '5. volume': '32661600'},
#   '2004-08-13': {'1. open': '29.8500',
#    '2. high': '31.5400',
#    '3. low': '29.8100',
#    '4. close': '30.8400',
#    '5. volume': '27116500'},
#   '2004-08-06': {'1. open': '31.1800',
#    '2. high': '32.3000',
#    '3. low': '29.7000',
#    '4. close': '29.7800',
#    '5. volume': '28392900'},
#   '2004-07-30': {'1. open': '30.8500',
#    '2. high': '33.0000',
#    '3. low': '30.7800',
#    '4. close': '32.3400',
#    '5. volume': '28020900'},
#   '2004-07-23': {'1. open': '32.0500',
#    '2. high': '32.7100',
#    '3. low': '30.4800',
#    '4. close': '30.7000',
#    '5. volume': '31533300'},
#   '2004-07-16': {'1. open': '30.0100',
#    '2. high': '33.6300',
#    '3. low': '28.7400',
#    '4. close': '32.2000',
#    '5. volume': '69994700'},
#   '2004-07-09': {'1. open': '31.2700',
#    '2. high': '31.4200',
#    '3. low': '29.9500',
#    '4. close': '30.0300',
#    '5. volume': '21236000'},
#   '2004-07-02': {'1. open': '33.9000',
#    '2. high': '34.1900',
#    '3. low': '29.7300',
#    '4. close': '31.0800',
#    '5. volume': '48880700'},
#   '2004-06-25': {'1. open': '33.1000',
#    '2. high': '33.8300',
#    '3. low': '32.1200',
#    '4. close': '33.7000',
#    '5. volume': '30670300'},
#   '2004-06-18': {'1. open': '30.6500',
#    '2. high': '33.4090',
#    '3. low': '29.5000',
#    '4. close': '32.9100',
#    '5. volume': '45639900'},
#   '2004-06-10': {'1. open': '29.0400',
#    '2. high': '30.9700',
#    '3. low': '28.8100',
#    '4. close': '30.7400',
#    '5. volume': '23540700'},
#   '2004-06-04': {'1. open': '27.7900',
#    '2. high': '29.2500',
#    '3. low': '27.6100',
#    '4. close': '28.7800',
#    '5. volume': '20551600'},
#   '2004-05-28': {'1. open': '27.2500',
#    '2. high': '28.7800',
#    '3. low': '27.1100',
#    '4. close': '28.0600',
#    '5. volume': '22490000'},
#   '2004-05-21': {'1. open': '26.7000',
#    '2. high': '27.5000',
#    '3. low': '26.3600',
#    '4. close': '27.1100',
#    '5. volume': '22469500'},
#   '2004-05-14': {'1. open': '26.2700',
#    '2. high': '27.7200',
#    '3. low': '25.9400',
#    '4. close': '27.0600',
#    '5. volume': '23004000'},
#   '2004-05-07': {'1. open': '26.0000',
#    '2. high': '27.5700',
#    '3. low': '25.5000',
#    '4. close': '26.6700',
#    '5. volume': '26755700'},
#   '2004-04-30': {'1. open': '27.5800',
#    '2. high': '27.6350',
#    '3. low': '25.4900',
#    '4. close': '25.7800',
#    '5. volume': '29883100'},
#   '2004-04-23': {'1. open': '28.1200',
#    '2. high': '28.7500',
#    '3. low': '27.0500',
#    '4. close': '27.7000',
#    '5. volume': '36663600'},
#   '2004-04-16': {'1. open': '27.5000',
#    '2. high': '29.5800',
#    '3. low': '26.3100',
#    '4. close': '29.1800',
#    '5. volume': '61983000'},
#   '2004-04-08': {'1. open': '27.4800',
#    '2. high': '28.3700',
#    '3. low': '26.9200',
#    '4. close': '27.5300',
#    '5. volume': '20351800'},
#   '2004-04-02': {'1. open': '27.4000',
#    '2. high': '27.9900',
#    '3. low': '26.6200',
#    '4. close': '27.5000',
#    '5. volume': '30249800'},
#   '2004-03-26': {'1. open': '25.3700',
#    '2. high': '27.3600',
#    '3. low': '25.2200',
#    '4. close': '27.0400',
#    '5. volume': '39626800'},
#   '2004-03-19': {'1. open': '27.0300',
#    '2. high': '27.3500',
#    '3. low': '25.3900',
#    '4. close': '25.8600',
#    '5. volume': '39790000'},
#   '2004-03-12': {'1. open': '26.7900',
#    '2. high': '28.1400',
#    '3. low': '25.7500',
#    '4. close': '27.5600',
#    '5. volume': '54879900'},
#   '2004-03-05': {'1. open': '24.0900',
#    '2. high': '27.4900',
#    '3. low': '23.6000',
#    '4. close': '26.7400',
#    '5. volume': '53648600'},
#   '2004-02-27': {'1. open': '22.4500',
#    '2. high': '24.0200',
#    '3. low': '21.8899',
#    '4. close': '23.9200',
#    '5. volume': '24940300'},
#   ...},
#  {'1. Information': 'Weekly Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-04-21',
#   '4. Time Zone': 'US/Eastern'})

# %%
#get intraday stock data of Apple
ts1.get_intraday('AAPL')
# Out:
# ({'2023-04-21 20:00:00': {'1. open': '164.9200',
#    '2. high': '165.0000',
#    '3. low': '164.9200',
#    '4. close': '164.9201',
#    '5. volume': '5051'},
#   '2023-04-21 19:45:00': {'1. open': '164.9400',
#    '2. high': '164.9400',
#    '3. low': '164.9000',
#    '4. close': '164.9000',
#    '5. volume': '3592'},
#   '2023-04-21 19:30:00': {'1. open': '164.9400',
#    '2. high': '164.9400',
#    '3. low': '164.9400',
#    '4. close': '164.9400',
#    '5. volume': '246'},
#   '2023-04-21 19:15:00': {'1. open': '164.9000',
#    '2. high': '164.9600',
#    '3. low': '164.9000',
#    '4. close': '164.9600',
#    '5. volume': '1150'},
#   '2023-04-21 19:00:00': {'1. open': '164.9600',
#    '2. high': '164.9600',
#    '3. low': '164.9100',
#    '4. close': '164.9100',
#    '5. volume': '5659'},
#   '2023-04-21 18:45:00': {'1. open': '164.9500',
#    '2. high': '164.9800',
#    '3. low': '164.9500',
#    '4. close': '164.9800',
#    '5. volume': '3744'},
#   '2023-04-21 18:30:00': {'1. open': '164.9600',
#    '2. high': '164.9600',
#    '3. low': '164.9500',
#    '4. close': '164.9500',
#    '5. volume': '3284'},
#   '2023-04-21 18:15:00': {'1. open': '164.9501',
#    '2. high': '165.0000',
#    '3. low': '164.9500',
#    '4. close': '164.9500',
#    '5. volume': '2601'},
#   '2023-04-21 18:00:00': {'1. open': '164.9715',
#    '2. high': '165.0000',
#    '3. low': '164.9500',
#    '4. close': '164.9500',
#    '5. volume': '3277'},
#   '2023-04-21 17:45:00': {'1. open': '164.9700',
#    '2. high': '165.0200',
#    '3. low': '164.9700',
#    '4. close': '165.0000',
#    '5. volume': '280403'},
#   '2023-04-21 17:30:00': {'1. open': '164.9900',
#    '2. high': '165.0000',
#    '3. low': '164.9900',
#    '4. close': '164.9900',
#    '5. volume': '2788'},
#   '2023-04-21 17:15:00': {'1. open': '164.9800',
#    '2. high': '165.0000',
#    '3. low': '164.9800',
#    '4. close': '164.9900',
#    '5. volume': '1152895'},
#   '2023-04-21 17:00:00': {'1. open': '164.9800',
#    '2. high': '164.9900',
#    '3. low': '164.9800',
#    '4. close': '164.9800',
#    '5. volume': '11958'},
#   '2023-04-21 16:45:00': {'1. open': '165.0000',
#    '2. high': '165.0200',
#    '3. low': '164.9800',
#    '4. close': '164.9801',
#    '5. volume': '24310'},
#   '2023-04-21 16:30:00': {'1. open': '164.9800',
#    '2. high': '165.0300',
#    '3. low': '164.9700',
#    '4. close': '165.0000',
#    '5. volume': '60469'},
#   '2023-04-21 16:15:00': {'1. open': '165.0200',
#    '2. high': '165.0700',
#    '3. low': '164.9700',
#    '4. close': '164.9700',
#    '5. volume': '1186644'},
#   '2023-04-21 16:00:00': {'1. open': '164.8050',
#    '2. high': '165.0600',
#    '3. low': '164.7650',
#    '4. close': '165.0200',
#    '5. volume': '3400815'},
#   '2023-04-21 15:45:00': {'1. open': '164.9550',
#    '2. high': '165.0500',
#    '3. low': '164.6900',
#    '4. close': '164.8050',
#    '5. volume': '1841172'},
#   '2023-04-21 15:30:00': {'1. open': '164.7400',
#    '2. high': '164.9800',
#    '3. low': '164.7150',
#    '4. close': '164.9575',
#    '5. volume': '2314918'},
#   '2023-04-21 15:15:00': {'1. open': '165.0328',
#    '2. high': '165.0650',
#    '3. low': '164.7200',
#    '4. close': '164.7500',
#    '5. volume': '1252064'},
#   '2023-04-21 15:00:00': {'1. open': '164.9914',
#    '2. high': '165.0850',
#    '3. low': '164.8800',
#    '4. close': '165.0350',
#    '5. volume': '992606'},
#   '2023-04-21 14:45:00': {'1. open': '165.2785',
#    '2. high': '165.3600',
#    '3. low': '164.9348',
#    '4. close': '164.9923',
#    '5. volume': '1326042'},
#   '2023-04-21 14:30:00': {'1. open': '165.2000',
#    '2. high': '165.3650',
#    '3. low': '165.0340',
#    '4. close': '165.2750',
#    '5. volume': '1381159'},
#   '2023-04-21 14:15:00': {'1. open': '165.0750',
#    '2. high': '165.2500',
#    '3. low': '165.0200',
#    '4. close': '165.1825',
#    '5. volume': '1210931'},
#   '2023-04-21 14:00:00': {'1. open': '164.9900',
#    '2. high': '165.1000',
#    '3. low': '164.8900',
#    '4. close': '165.0750',
#    '5. volume': '1012069'},
#   '2023-04-21 13:45:00': {'1. open': '164.7999',
#    '2. high': '165.0550',
#    '3. low': '164.7100',
#    '4. close': '164.9934',
#    '5. volume': '1290441'},
#   '2023-04-21 13:30:00': {'1. open': '165.0533',
#    '2. high': '165.1409',
#    '3. low': '164.6800',
#    '4. close': '164.7975',
#    '5. volume': '1087422'},
#   '2023-04-21 13:15:00': {'1. open': '164.8950',
#    '2. high': '165.2100',
#    '3. low': '164.8500',
#    '4. close': '165.0507',
#    '5. volume': '1040969'},
#   '2023-04-21 13:00:00': {'1. open': '164.7900',
#    '2. high': '165.0600',
#    '3. low': '164.7550',
#    '4. close': '164.9000',
#    '5. volume': '847577'},
#   '2023-04-21 12:45:00': {'1. open': '164.9250',
#    '2. high': '165.0200',
#    '3. low': '164.7450',
#    '4. close': '164.7900',
#    '5. volume': '900447'},
#   '2023-04-21 12:30:00': {'1. open': '164.9900',
#    '2. high': '165.1800',
#    '3. low': '164.8802',
#    '4. close': '164.9291',
#    '5. volume': '1068905'},
#   '2023-04-21 12:15:00': {'1. open': '165.2200',
#    '2. high': '165.2400',
#    '3. low': '164.8483',
#    '4. close': '164.9826',
#    '5. volume': '951620'},
#   '2023-04-21 12:00:00': {'1. open': '165.1500',
#    '2. high': '165.2400',
#    '3. low': '164.8100',
#    '4. close': '165.2200',
#    '5. volume': '1123684'},
#   '2023-04-21 11:45:00': {'1. open': '165.1000',
#    '2. high': '165.4200',
#    '3. low': '164.9628',
#    '4. close': '165.1499',
#    '5. volume': '1347734'},
#   '2023-04-21 11:30:00': {'1. open': '164.8950',
#    '2. high': '165.1500',
#    '3. low': '164.7100',
#    '4. close': '165.0900',
#    '5. volume': '1384548'},
#   '2023-04-21 11:15:00': {'1. open': '165.0200',
#    '2. high': '165.3250',
#    '3. low': '164.7900',
#    '4. close': '164.9000',
#    '5. volume': '1758084'},
#   '2023-04-21 11:00:00': {'1. open': '164.8500',
#    '2. high': '165.0350',
#    '3. low': '164.4900',
#    '4. close': '165.0100',
#    '5. volume': '2444214'},
#   '2023-04-21 10:45:00': {'1. open': '165.3700',
#    '2. high': '165.4600',
#    '3. low': '164.8000',
#    '4. close': '164.8501',
#    '5. volume': '1890896'},
#   '2023-04-21 10:30:00': {'1. open': '165.0450',
#    '2. high': '165.6800',
#    '3. low': '165.0426',
#    '4. close': '165.3798',
#    '5. volume': '2102404'},
#   '2023-04-21 10:15:00': {'1. open': '164.8950',
#    '2. high': '165.1750',
#    '3. low': '164.7200',
#    '4. close': '165.0400',
#    '5. volume': '2763560'},
#   '2023-04-21 10:00:00': {'1. open': '165.8400',
#    '2. high': '165.9399',
#    '3. low': '164.8700',
#    '4. close': '164.9000',
#    '5. volume': '3311129'},
#   '2023-04-21 09:45:00': {'1. open': '165.0500',
#    '2. high': '166.4521',
#    '3. low': '164.6700',
#    '4. close': '165.8300',
#    '5. volume': '8054313'},
#   '2023-04-21 09:30:00': {'1. open': '164.6900',
#    '2. high': '165.4000',
#    '3. low': '164.5800',
#    '4. close': '165.0500',
#    '5. volume': '432448'},
#   '2023-04-21 09:15:00': {'1. open': '164.6200',
#    '2. high': '164.8400',
#    '3. low': '164.4100',
#    '4. close': '164.6900',
#    '5. volume': '145623'},
#   '2023-04-21 09:00:00': {'1. open': '164.4500',
#    '2. high': '164.6900',
#    '3. low': '164.3000',
#    '4. close': '164.6200',
#    '5. volume': '94558'},
#   '2023-04-21 08:45:00': {'1. open': '164.6600',
#    '2. high': '164.6800',
#    '3. low': '164.2100',
#    '4. close': '164.3220',
#    '5. volume': '126312'},
#   '2023-04-21 08:30:00': {'1. open': '164.3500',
#    '2. high': '164.7489',
#    '3. low': '164.1000',
#    '4. close': '164.7489',
#    '5. volume': '114951'},
#   '2023-04-21 08:15:00': {'1. open': '164.3500',
#    '2. high': '166.4400',
#    '3. low': '163.8000',
#    '4. close': '164.3500',
#    '5. volume': '172236'},
#   '2023-04-21 08:00:00': {'1. open': '164.1600',
#    '2. high': '164.2500',
#    '3. low': '163.8900',
#    '4. close': '164.0000',
#    '5. volume': '85588'},
#   '2023-04-21 07:45:00': {'1. open': '164.3300',
#    '2. high': '164.4000',
#    '3. low': '164.0500',
#    '4. close': '164.1800',
#    '5. volume': '100290'},
#   '2023-04-21 07:30:00': {'1. open': '164.2400',
#    '2. high': '164.4900',
#    '3. low': '164.2000',
#    '4. close': '164.2700',
#    '5. volume': '53285'},
#   '2023-04-21 07:15:00': {'1. open': '163.9700',
#    '2. high': '164.4900',
#    '3. low': '163.9700',
#    '4. close': '164.2000',
#    '5. volume': '143971'},
#   '2023-04-21 07:00:00': {'1. open': '163.7000',
#    '2. high': '164.2300',
#    '3. low': '163.6600',
#    '4. close': '163.7700',
#    '5. volume': '64523'},
#   '2023-04-21 06:45:00': {'1. open': '166.3800',
#    '2. high': '166.3800',
#    '3. low': '162.9900',
#    '4. close': '163.7100',
#    '5. volume': '204757'},
#   '2023-04-21 06:30:00': {'1. open': '166.4700',
#    '2. high': '166.4700',
#    '3. low': '166.3700',
#    '4. close': '166.3800',
#    '5. volume': '1283'},
#   '2023-04-21 06:15:00': {'1. open': '166.5700',
#    '2. high': '166.5700',
#    '3. low': '166.5500',
#    '4. close': '166.5500',
#    '5. volume': '702'},
#   '2023-04-21 06:00:00': {'1. open': '166.6100',
#    '2. high': '166.6100',
#    '3. low': '166.6100',
#    '4. close': '166.6100',
#    '5. volume': '813'},
#   '2023-04-21 05:45:00': {'1. open': '166.5500',
#    '2. high': '166.6600',
#    '3. low': '166.5200',
#    '4. close': '166.6600',
#    '5. volume': '2197'},
#   '2023-04-21 05:30:00': {'1. open': '166.5600',
#    '2. high': '166.5600',
#    '3. low': '166.5600',
#    '4. close': '166.5600',
#    '5. volume': '412'},
#   '2023-04-21 05:15:00': {'1. open': '166.6000',
#    '2. high': '166.6000',
#    '3. low': '166.5000',
#    '4. close': '166.5000',
#    '5. volume': '1122'},
#   '2023-04-21 05:00:00': {'1. open': '166.5000',
#    '2. high': '166.6000',
#    '3. low': '166.5000',
#    '4. close': '166.5800',
#    '5. volume': '2547'},
#   '2023-04-21 04:45:00': {'1. open': '166.3200',
#    '2. high': '166.4000',
#    '3. low': '166.3200',
#    '4. close': '166.4000',
#    '5. volume': '1733'},
#   '2023-04-21 04:30:00': {'1. open': '166.4300',
#    '2. high': '166.4500',
#    '3. low': '166.3300',
#    '4. close': '166.3400',
#    '5. volume': '2184'},
#   '2023-04-21 04:15:00': {'1. open': '166.6800',
#    '2. high': '166.6800',
#    '3. low': '166.5000',
#    '4. close': '166.5600',
#    '5. volume': '7207'},
#   '2023-04-20 20:00:00': {'1. open': '166.7600',
#    '2. high': '166.9800',
#    '3. low': '166.7000',
#    '4. close': '166.9800',
#    '5. volume': '17199'},
#   '2023-04-20 19:45:00': {'1. open': '166.8600',
#    '2. high': '166.9000',
#    '3. low': '166.7300',
#    '4. close': '166.7500',
#    '5. volume': '13753'},
#   '2023-04-20 19:30:00': {'1. open': '166.7800',
#    '2. high': '166.8600',
#    '3. low': '166.7300',
#    '4. close': '166.8600',
#    '5. volume': '7145'},
#   '2023-04-20 19:15:00': {'1. open': '166.7400',
#    '2. high': '166.8500',
#    '3. low': '166.7200',
#    '4. close': '166.7200',
#    '5. volume': '14237'},
#   '2023-04-20 19:00:00': {'1. open': '166.7000',
#    '2. high': '166.7400',
#    '3. low': '166.7000',
#    '4. close': '166.7200',
#    '5. volume': '16908'},
#   '2023-04-20 18:45:00': {'1. open': '166.7000',
#    '2. high': '166.7700',
#    '3. low': '166.7000',
#    '4. close': '166.7100',
#    '5. volume': '14194'},
#   '2023-04-20 18:30:00': {'1. open': '166.6800',
#    '2. high': '166.7000',
#    '3. low': '166.6400',
#    '4. close': '166.6700',
#    '5. volume': '7548'},
#   '2023-04-20 18:15:00': {'1. open': '166.6600',
#    '2. high': '166.7400',
#    '3. low': '166.6100',
#    '4. close': '166.7400',
#    '5. volume': '28574'},
#   '2023-04-20 18:00:00': {'1. open': '166.6200',
#    '2. high': '166.6900',
#    '3. low': '166.6200',
#    '4. close': '166.6600',
#    '5. volume': '1825'},
#   '2023-04-20 17:45:00': {'1. open': '166.6200',
#    '2. high': '166.6600',
#    '3. low': '166.6200',
#    '4. close': '166.6600',
#    '5. volume': '1847'},
#   '2023-04-20 17:30:00': {'1. open': '166.6200',
#    '2. high': '166.6500',
#    '3. low': '166.6200',
#    '4. close': '166.6300',
#    '5. volume': '1138'},
#   '2023-04-20 17:15:00': {'1. open': '166.6110',
#    '2. high': '166.6500',
#    '3. low': '166.6100',
#    '4. close': '166.6500',
#    '5. volume': '40910'},
#   '2023-04-20 17:00:00': {'1. open': '166.6500',
#    '2. high': '166.6773',
#    '3. low': '166.5800',
#    '4. close': '166.6300',
#    '5. volume': '23396'},
#   '2023-04-20 16:45:00': {'1. open': '166.7300',
#    '2. high': '166.7600',
#    '3. low': '166.6500',
#    '4. close': '166.6500',
#    '5. volume': '39138'},
#   '2023-04-20 16:30:00': {'1. open': '166.7200',
#    '2. high': '166.7300',
#    '3. low': '166.6500',
#    '4. close': '166.7300',
#    '5. volume': '30660'},
#   '2023-04-20 16:15:00': {'1. open': '166.6500',
#    '2. high': '166.7800',
#    '3. low': '166.5500',
#    '4. close': '166.7300',
#    '5. volume': '2227681'},
#   '2023-04-20 16:00:00': {'1. open': '165.8400',
#    '2. high': '166.6700',
#    '3. low': '165.8000',
#    '4. close': '166.6500',
#    '5. volume': '3867994'},
#   '2023-04-20 15:45:00': {'1. open': '165.6250',
#    '2. high': '166.0659',
#    '3. low': '165.6250',
#    '4. close': '165.8300',
#    '5. volume': '2176330'},
#   '2023-04-20 15:30:00': {'1. open': '166.0300',
#    '2. high': '166.0750',
#    '3. low': '165.5600',
#    '4. close': '165.6200',
#    '5. volume': '2503582'},
#   '2023-04-20 15:15:00': {'1. open': '166.5600',
#    '2. high': '166.6400',
#    '3. low': '166.0000',
#    '4. close': '166.0312',
#    '5. volume': '1849409'},
#   '2023-04-20 15:00:00': {'1. open': '166.3400',
#    '2. high': '166.6000',
#    '3. low': '166.2500',
#    '4. close': '166.5600',
#    '5. volume': '1392052'},
#   '2023-04-20 14:45:00': {'1. open': '166.8600',
#    '2. high': '166.8900',
#    '3. low': '166.2301',
#    '4. close': '166.3401',
#    '5. volume': '1838777'},
#   '2023-04-20 14:30:00': {'1. open': '167.3600',
#    '2. high': '167.3800',
#    '3. low': '166.8300',
#    '4. close': '166.8700',
#    '5. volume': '1380328'},
#   '2023-04-20 14:15:00': {'1. open': '167.4700',
#    '2. high': '167.5000',
#    '3. low': '167.2600',
#    '4. close': '167.3628',
#    '5. volume': '1135194'},
#   '2023-04-20 14:00:00': {'1. open': '167.6545',
#    '2. high': '167.7500',
#    '3. low': '167.4500',
#    '4. close': '167.4700',
#    '5. volume': '752043'},
#   '2023-04-20 13:45:00': {'1. open': '167.6100',
#    '2. high': '167.7200',
#    '3. low': '167.4400',
#    '4. close': '167.6599',
#    '5. volume': '923391'},
#   '2023-04-20 13:30:00': {'1. open': '167.8400',
#    '2. high': '167.8400',
#    '3. low': '167.6000',
#    '4. close': '167.6009',
#    '5. volume': '872073'},
#   '2023-04-20 13:15:00': {'1. open': '167.6950',
#    '2. high': '167.8600',
#    '3. low': '167.5600',
#    '4. close': '167.8400',
#    '5. volume': '1084091'},
#   '2023-04-20 13:00:00': {'1. open': '167.4350',
#    '2. high': '167.7400',
#    '3. low': '167.4300',
#    '4. close': '167.7000',
#    '5. volume': '909239'},
#   '2023-04-20 12:45:00': {'1. open': '167.4100',
#    '2. high': '167.8700',
#    '3. low': '167.3800',
#    '4. close': '167.4384',
#    '5. volume': '1389874'},
#   '2023-04-20 12:30:00': {'1. open': '167.1800',
#    '2. high': '167.4900',
#    '3. low': '167.1417',
#    '4. close': '167.4100',
#    '5. volume': '896199'},
#   '2023-04-20 12:15:00': {'1. open': '167.2800',
#    '2. high': '167.3279',
#    '3. low': '166.9600',
#    '4. close': '167.1750',
#    '5. volume': '1110363'},
#   '2023-04-20 12:00:00': {'1. open': '167.3250',
#    '2. high': '167.5400',
#    '3. low': '167.2500',
#    '4. close': '167.2800',
#    '5. volume': '1252937'},
#   '2023-04-20 11:45:00': {'1. open': '167.1424',
#    '2. high': '167.4400',
#    '3. low': '166.9000',
#    '4. close': '167.3299',
#    '5. volume': '1406169'},
#   '2023-04-20 11:30:00': {'1. open': '166.8200',
#    '2. high': '167.1700',
#    '3. low': '166.6200',
#    '4. close': '167.1400',
#    '5. volume': '1461741'},
#   '2023-04-20 11:15:00': {'1. open': '166.8700',
#    '2. high': '166.9500',
#    '3. low': '166.5100',
#    '4. close': '166.8200',
#    '5. volume': '1202593'}},
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-04-21 20:00:00',
#   '4. Interval': '15min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'})
