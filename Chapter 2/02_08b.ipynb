# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&apikey=' + str(API_key) + "&datatype=csv"
r = requests.get(url).content
data = pd.read_csv(io.StringIO(r.decode("utf-8")))

print(data)
# Out:
#        timestamp    open    high     low   close     volume
# 0     2023-08-18  177.97  179.69  171.96  174.49  261498109
# 1     2023-08-11  182.13  183.13  176.55  177.79  332501087
# 2     2023-08-04  196.06  196.73  181.92  181.99  302694989
# 3     2023-07-28  193.41  197.20  192.25  195.83  226011789
# 4     2023-07-21  191.90  198.23  191.23  191.94  310914135
# ...          ...     ...     ...     ...     ...        ...
# 1236  1999-12-10  114.56  118.00   99.00  103.00   25152800
# 1237  1999-12-03   94.25  115.56   93.25  115.00   28046300
# 1238  1999-11-26   91.75   95.50   88.50   95.06    9757600
# 1239  1999-11-19   89.62   94.75   88.06   92.44   13711000
# 1240  1999-11-12   87.75   97.73   86.75   90.62   25776200
#
# [1241 rows x 6 columns]

# %%
#get head of data
data.head(10)
# Out:
#     timestamp    open    high       low   close     volume
# 0  2023-08-18  177.97  179.69  171.9600  174.49  261498109
# 1  2023-08-11  182.13  183.13  176.5500  177.79  332501087
# 2  2023-08-04  196.06  196.73  181.9200  181.99  302694989
# 3  2023-07-28  193.41  197.20  192.2500  195.83  226011789
# 4  2023-07-21  191.90  198.23  191.2300  191.94  310914135
# 5  2023-07-14  189.26  191.70  186.6000  190.69  250269110
# 6  2023-07-07  193.78  193.88  189.2000  190.68  170349466
# 7  2023-06-30  186.83  194.48  185.2300  193.97  281596832
# 8  2023-06-23  184.41  187.56  182.5901  186.68  203677112
# 9  2023-06-16  181.27  186.99  180.9700  184.92  333836397

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data = ts1.get_intraday("AAPL")

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-08-18 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data
apple1
# Out:
# {'2023-08-18 19:45:00': {'1. open': '174.5400',
#   '2. high': '174.7000',
#   '3. low': '174.5000',
#   '4. close': '174.7000',
#   '5. volume': '8691'},
#  '2023-08-18 19:30:00': {'1. open': '174.4700',
#   '2. high': '174.5900',
#   '3. low': '174.4700',
#   '4. close': '174.5600',
#   '5. volume': '11647'},
#  '2023-08-18 19:15:00': {'1. open': '174.4800',
#   '2. high': '174.5400',
#   '3. low': '174.4700',
#   '4. close': '174.4900',
#   '5. volume': '16188'},
#  '2023-08-18 19:00:00': {'1. open': '174.5500',
#   '2. high': '174.5500',
#   '3. low': '174.4700',
#   '4. close': '174.4800',
#   '5. volume': '4915'},
#  '2023-08-18 18:45:00': {'1. open': '174.5500',
#   '2. high': '174.5800',
#   '3. low': '174.5000',
#   '4. close': '174.5250',
#   '5. volume': '4517'},
#  '2023-08-18 18:30:00': {'1. open': '174.5800',
#   '2. high': '174.6200',
#   '3. low': '174.4700',
#   '4. close': '174.5500',
#   '5. volume': '6709'},
#  '2023-08-18 18:15:00': {'1. open': '174.5900',
#   '2. high': '174.6000',
#   '3. low': '174.5400',
#   '4. close': '174.5800',
#   '5. volume': '4425'},
#  '2023-08-18 18:00:00': {'1. open': '174.5350',
#   '2. high': '174.5900',
#   '3. low': '174.4900',
#   '4. close': '174.5900',
#   '5. volume': '4720'},
#  '2023-08-18 17:45:00': {'1. open': '174.5400',
#   '2. high': '174.5900',
#   '3. low': '174.5200',
#   '4. close': '174.5400',
#   '5. volume': '7644'},
#  '2023-08-18 17:30:00': {'1. open': '181.6570',
#   '2. high': '181.6570',
#   '3. low': '174.5000',
#   '4. close': '174.5600',
#   '5. volume': '8864'},
#  '2023-08-18 17:15:00': {'1. open': '174.3950',
#   '2. high': '177.9770',
#   '3. low': '164.2920',
#   '4. close': '174.4900',
#   '5. volume': '5972'},
#  '2023-08-18 17:00:00': {'1. open': '174.3400',
#   '2. high': '177.1900',
#   '3. low': '173.6900',
#   '4. close': '174.4200',
#   '5. volume': '6756'},
#  '2023-08-18 16:45:00': {'1. open': '174.4600',
#   '2. high': '174.4900',
#   '3. low': '174.2700',
#   '4. close': '174.3500',
#   '5. volume': '2656277'},
#  '2023-08-18 16:30:00': {'1. open': '174.4500',
#   '2. high': '178.9670',
#   '3. low': '174.4400',
#   '4. close': '174.4400',
#   '5. volume': '450297'},
#  '2023-08-18 16:15:00': {'1. open': '174.5300',
#   '2. high': '174.5600',
#   '3. low': '174.4000',
#   '4. close': '174.4500',
#   '5. volume': '16650'},
#  '2023-08-18 16:00:00': {'1. open': '174.5000',
#   '2. high': '174.6700',
#   '3. low': '174.4300',
#   '4. close': '174.5600',
#   '5. volume': '18406088'},
#  '2023-08-18 15:45:00': {'1. open': '174.7800',
#   '2. high': '175.1000',
#   '3. low': '174.1500',
#   '4. close': '174.4900',
#   '5. volume': '5045778'},
#  '2023-08-18 15:30:00': {'1. open': '174.4900',
#   '2. high': '174.8000',
#   '3. low': '174.3800',
#   '4. close': '174.7900',
#   '5. volume': '1193495'},
#  '2023-08-18 15:15:00': {'1. open': '174.1800',
#   '2. high': '174.5500',
#   '3. low': '174.1400',
#   '4. close': '174.4950',
#   '5. volume': '1184796'},
#  '2023-08-18 15:00:00': {'1. open': '174.4250',
#   '2. high': '174.5000',
#   '3. low': '174.0950',
#   '4. close': '174.1800',
#   '5. volume': '1170703'},
#  '2023-08-18 14:45:00': {'1. open': '174.6450',
#   '2. high': '174.7900',
#   '3. low': '174.3400',
#   '4. close': '174.4200',
#   '5. volume': '998479'},
#  '2023-08-18 14:30:00': {'1. open': '174.5350',
#   '2. high': '174.8800',
#   '3. low': '174.4600',
#   '4. close': '174.6450',
#   '5. volume': '1215964'},
#  '2023-08-18 14:15:00': {'1. open': '174.4800',
#   '2. high': '174.6480',
#   '3. low': '173.5700',
#   '4. close': '174.5500',
#   '5. volume': '984850'},
#  '2023-08-18 14:00:00': {'1. open': '174.4100',
#   '2. high': '174.7500',
#   '3. low': '173.5700',
#   '4. close': '174.4780',
#   '5. volume': '1626516'},
#  '2023-08-18 13:45:00': {'1. open': '174.3100',
#   '2. high': '174.4700',
#   '3. low': '174.2400',
#   '4. close': '174.4100',
#   '5. volume': '750562'},
#  '2023-08-18 13:30:00': {'1. open': '174.2750',
#   '2. high': '174.4100',
#   '3. low': '174.1250',
#   '4. close': '174.3000',
#   '5. volume': '1078475'},
#  '2023-08-18 13:15:00': {'1. open': '174.2200',
#   '2. high': '174.3600',
#   '3. low': '173.6000',
#   '4. close': '174.2750',
#   '5. volume': '2814212'},
#  '2023-08-18 13:00:00': {'1. open': '173.9800',
#   '2. high': '174.2800',
#   '3. low': '173.8700',
#   '4. close': '174.2200',
#   '5. volume': '1021794'},
#  '2023-08-18 12:45:00': {'1. open': '174.2200',
#   '2. high': '174.3650',
#   '3. low': '173.9300',
#   '4. close': '173.9780',
#   '5. volume': '927022'},
#  '2023-08-18 12:30:00': {'1. open': '173.8200',
#   '2. high': '174.2300',
#   '3. low': '173.8000',
#   '4. close': '174.2150',
#   '5. volume': '1017724'},
#  '2023-08-18 12:15:00': {'1. open': '174.0200',
#   '2. high': '174.0600',
#   '3. low': '173.7000',
#   '4. close': '173.8200',
#   '5. volume': '1245276'},
#  '2023-08-18 12:00:00': {'1. open': '174.3000',
#   '2. high': '174.4400',
#   '3. low': '173.9300',
#   '4. close': '174.0290',
#   '5. volume': '1306078'},
#  '2023-08-18 11:45:00': {'1. open': '173.6950',
#   '2. high': '174.3700',
#   '3. low': '173.6300',
#   '4. close': '174.3150',
#   '5. volume': '1362833'},
#  '2023-08-18 11:30:00': {'1. open': '173.4500',
#   '2. high': '173.7300',
#   '3. low': '173.2810',
#   '4. close': '173.6980',
#   '5. volume': '1468538'},
#  '2023-08-18 11:15:00': {'1. open': '173.6500',
#   '2. high': '173.9000',
#   '3. low': '173.4500',
#   '4. close': '173.4600',
#   '5. volume': '2165683'},
#  '2023-08-18 11:00:00': {'1. open': '173.7060',
#   '2. high': '173.9500',
#   '3. low': '173.3300',
#   '4. close': '173.6500',
#   '5. volume': '1479546'},
#  '2023-08-18 10:45:00': {'1. open': '173.6400',
#   '2. high': '173.7700',
#   '3. low': '173.2800',
#   '4. close': '173.7100',
#   '5. volume': '1563374'},
#  '2023-08-18 10:30:00': {'1. open': '172.8100',
#   '2. high': '173.7500',
#   '3. low': '172.7600',
#   '4. close': '173.6320',
#   '5. volume': '2180085'},
#  '2023-08-18 10:15:00': {'1. open': '173.0800',
#   '2. high': '173.3600',
#   '3. low': '172.6400',
#   '4. close': '172.8000',
#   '5. volume': '2377121'},
#  '2023-08-18 10:00:00': {'1. open': '172.4600',
#   '2. high': '173.1200',
#   '3. low': '172.4310',
#   '4. close': '173.0810',
#   '5. volume': '2111415'},
#  '2023-08-18 09:45:00': {'1. open': '172.7700',
#   '2. high': '173.1100',
#   '3. low': '172.3400',
#   '4. close': '172.4800',
#   '5. volume': '2295024'},
#  '2023-08-18 09:30:00': {'1. open': '172.3000',
#   '2. high': '173.3500',
#   '3. low': '171.9600',
#   '4. close': '172.7900',
#   '5. volume': '5976282'},
#  '2023-08-18 09:15:00': {'1. open': '172.7000',
#   '2. high': '172.8000',
#   '3. low': '171.7000',
#   '4. close': '172.3100',
#   '5. volume': '278012'},
#  '2023-08-18 09:00:00': {'1. open': '172.4900',
#   '2. high': '172.7650',
#   '3. low': '172.2700',
#   '4. close': '172.7000',
#   '5. volume': '85498'},
#  '2023-08-18 08:45:00': {'1. open': '172.2500',
#   '2. high': '172.5900',
#   '3. low': '172.1500',
#   '4. close': '172.4850',
#   '5. volume': '88548'},
#  '2023-08-18 08:30:00': {'1. open': '172.2000',
#   '2. high': '172.3700',
#   '3. low': '172.0500',
#   '4. close': '172.2450',
#   '5. volume': '82146'},
#  '2023-08-18 08:15:00': {'1. open': '172.2200',
#   '2. high': '172.3250',
#   '3. low': '171.9800',
#   '4. close': '172.2050',
#   '5. volume': '97747'},
#  '2023-08-18 08:00:00': {'1. open': '173.0480',
#   '2. high': '174.2000',
#   '3. low': '171.9300',
#   '4. close': '172.2600',
#   '5. volume': '260439'},
#  '2023-08-18 07:45:00': {'1. open': '172.2200',
#   '2. high': '172.4200',
#   '3. low': '172.1000',
#   '4. close': '172.3500',
#   '5. volume': '71933'},
#  '2023-08-18 07:30:00': {'1. open': '172.1100',
#   '2. high': '172.2800',
#   '3. low': '171.9200',
#   '4. close': '172.2300',
#   '5. volume': '87614'},
#  '2023-08-18 07:15:00': {'1. open': '172.6900',
#   '2. high': '172.7400',
#   '3. low': '172.1000',
#   '4. close': '172.1000',
#   '5. volume': '56762'},
#  '2023-08-18 07:00:00': {'1. open': '173.0400',
#   '2. high': '173.1400',
#   '3. low': '172.6600',
#   '4. close': '172.6900',
#   '5. volume': '47420'},
#  '2023-08-18 06:45:00': {'1. open': '172.9700',
#   '2. high': '173.0400',
#   '3. low': '172.8800',
#   '4. close': '173.0400',
#   '5. volume': '9965'},
#  '2023-08-18 06:30:00': {'1. open': '173.0900',
#   '2. high': '173.1300',
#   '3. low': '172.9200',
#   '4. close': '172.9700',
#   '5. volume': '11329'},
#  '2023-08-18 06:15:00': {'1. open': '173.2800',
#   '2. high': '173.3100',
#   '3. low': '173.0900',
#   '4. close': '173.1100',
#   '5. volume': '7789'},
#  '2023-08-18 06:00:00': {'1. open': '173.2100',
#   '2. high': '173.2700',
#   '3. low': '173.1300',
#   '4. close': '173.2500',
#   '5. volume': '15596'},
#  '2023-08-18 05:45:00': {'1. open': '173.1100',
#   '2. high': '173.2400',
#   '3. low': '173.0600',
#   '4. close': '173.2100',
#   '5. volume': '6126'},
#  '2023-08-18 05:30:00': {'1. open': '173.2000',
#   '2. high': '173.4600',
#   '3. low': '173.0300',
#   '4. close': '173.1200',
#   '5. volume': '13611'},
#  '2023-08-18 05:15:00': {'1. open': '173.3000',
#   '2. high': '173.3900',
#   '3. low': '173.1900',
#   '4. close': '173.2000',
#   '5. volume': '4097'},
#  '2023-08-18 05:00:00': {'1. open': '173.5000',
#   '2. high': '173.6400',
#   '3. low': '173.1900',
#   '4. close': '173.3100',
#   '5. volume': '6165'},
#  '2023-08-18 04:45:00': {'1. open': '173.4200',
#   '2. high': '173.5500',
#   '3. low': '173.4000',
#   '4. close': '173.5000',
#   '5. volume': '2744'},
#  '2023-08-18 04:30:00': {'1. open': '173.3900',
#   '2. high': '173.5600',
#   '3. low': '173.3800',
#   '4. close': '173.4300',
#   '5. volume': '8726'},
#  '2023-08-18 04:15:00': {'1. open': '173.7200',
#   '2. high': '173.7800',
#   '3. low': '173.3700',
#   '4. close': '173.3900',
#   '5. volume': '8573'},
#  '2023-08-18 04:00:00': {'1. open': '174.1300',
#   '2. high': '174.1300',
#   '3. low': '173.3100',
#   '4. close': '173.7200',
#   '5. volume': '12981'},
#  '2023-08-17 19:45:00': {'1. open': '173.5800',
#   '2. high': '173.6400',
#   '3. low': '173.3200',
#   '4. close': '173.3600',
#   '5. volume': '16655'},
#  '2023-08-17 19:30:00': {'1. open': '173.4000',
#   '2. high': '173.6500',
#   '3. low': '173.3300',
#   '4. close': '173.5900',
#   '5. volume': '16210'},
#  '2023-08-17 19:15:00': {'1. open': '173.3800',
#   '2. high': '173.4100',
#   '3. low': '173.3300',
#   '4. close': '173.3900',
#   '5. volume': '9212'},
#  '2023-08-17 19:00:00': {'1. open': '173.3000',
#   '2. high': '173.4800',
#   '3. low': '173.2600',
#   '4. close': '173.3900',
#   '5. volume': '14110'},
#  '2023-08-17 18:45:00': {'1. open': '173.2200',
#   '2. high': '173.3600',
#   '3. low': '173.1300',
#   '4. close': '173.2700',
#   '5. volume': '18681'},
#  '2023-08-17 18:30:00': {'1. open': '173.3000',
#   '2. high': '173.3200',
#   '3. low': '173.1200',
#   '4. close': '173.2200',
#   '5. volume': '12943'},
#  '2023-08-17 18:15:00': {'1. open': '173.3500',
#   '2. high': '173.3600',
#   '3. low': '173.2500',
#   '4. close': '173.2900',
#   '5. volume': '17813'},
#  '2023-08-17 18:00:00': {'1. open': '173.3600',
#   '2. high': '173.5000',
#   '3. low': '173.2500',
#   '4. close': '173.3500',
#   '5. volume': '19617'},
#  '2023-08-17 17:45:00': {'1. open': '173.3800',
#   '2. high': '173.4300',
#   '3. low': '173.3000',
#   '4. close': '173.3600',
#   '5. volume': '15021'},
#  '2023-08-17 17:30:00': {'1. open': '173.2600',
#   '2. high': '173.6400',
#   '3. low': '173.1800',
#   '4. close': '173.3300',
#   '5. volume': '41537'},
#  '2023-08-17 17:15:00': {'1. open': '173.1700',
#   '2. high': '174.0000',
#   '3. low': '173.1100',
#   '4. close': '173.2800',
#   '5. volume': '106298'},
#  '2023-08-17 17:00:00': {'1. open': '173.4000',
#   '2. high': '174.4630',
#   '3. low': '173.1400',
#   '4. close': '173.1800',
#   '5. volume': '2438891'},
#  '2023-08-17 16:45:00': {'1. open': '173.4650',
#   '2. high': '174.0000',
#   '3. low': '173.3100',
#   '4. close': '173.4290',
#   '5. volume': '1884928'},
#  '2023-08-17 16:30:00': {'1. open': '173.5700',
#   '2. high': '174.0000',
#   '3. low': '173.4000',
#   '4. close': '173.4800',
#   '5. volume': '209341'},
#  '2023-08-17 16:15:00': {'1. open': '173.8000',
#   '2. high': '174.0000',
#   '3. low': '173.5300',
#   '4. close': '173.5900',
#   '5. volume': '80680'},
#  '2023-08-17 16:00:00': {'1. open': '173.9900',
#   '2. high': '174.1000',
#   '3. low': '173.5000',
#   '4. close': '173.8100',
#   '5. volume': '12033930'},
#  '2023-08-17 15:45:00': {'1. open': '173.8550',
#   '2. high': '174.8900',
#   '3. low': '173.7400',
#   '4. close': '173.9900',
#   '5. volume': '5064833'},
#  '2023-08-17 15:30:00': {'1. open': '174.0700',
#   '2. high': '174.2860',
#   '3. low': '173.6600',
#   '4. close': '173.8570',
#   '5. volume': '1850741'},
#  '2023-08-17 15:15:00': {'1. open': '173.7000',
#   '2. high': '174.1500',
#   '3. low': '173.4800',
#   '4. close': '174.0800',
#   '5. volume': '1864032'},
#  '2023-08-17 15:00:00': {'1. open': '173.9300',
#   '2. high': '174.0880',
#   '3. low': '173.6500',
#   '4. close': '173.7100',
#   '5. volume': '1649300'},
#  '2023-08-17 14:45:00': {'1. open': '174.0950',
#   '2. high': '174.2400',
#   '3. low': '173.7150',
#   '4. close': '173.9400',
#   '5. volume': '4210075'},
#  '2023-08-17 14:30:00': {'1. open': '174.2550',
#   '2. high': '174.2800',
#   '3. low': '173.9700',
#   '4. close': '174.1000',
#   '5. volume': '1094211'},
#  '2023-08-17 14:15:00': {'1. open': '174.2600',
#   '2. high': '174.2900',
#   '3. low': '173.9450',
#   '4. close': '174.2500',
#   '5. volume': '1107070'},
#  '2023-08-17 14:00:00': {'1. open': '174.2200',
#   '2. high': '174.3500',
#   '3. low': '173.9800',
#   '4. close': '174.2650',
#   '5. volume': '1017911'},
#  '2023-08-17 13:45:00': {'1. open': '174.1000',
#   '2. high': '174.3800',
#   '3. low': '174.0800',
#   '4. close': '174.2150',
#   '5. volume': '1099027'},
#  '2023-08-17 13:30:00': {'1. open': '174.5600',
#   '2. high': '174.5600',
#   '3. low': '174.0850',
#   '4. close': '174.1100',
#   '5. volume': '1134900'},
#  '2023-08-17 13:15:00': {'1. open': '174.9400',
#   '2. high': '175.0700',
#   '3. low': '174.5200',
#   '4. close': '174.5600',
#   '5. volume': '982691'},
#  '2023-08-17 13:00:00': {'1. open': '175.0700',
#   '2. high': '175.0900',
#   '3. low': '174.8110',
#   '4. close': '174.9300',
#   '5. volume': '1646659'},
#  '2023-08-17 12:45:00': {'1. open': '174.8650',
#   '2. high': '175.0650',
#   '3. low': '174.6620',
#   '4. close': '175.0650',
#   '5. volume': '1012589'},
#  '2023-08-17 12:30:00': {'1. open': '174.9600',
#   '2. high': '174.9900',
#   '3. low': '174.6400',
#   '4. close': '174.8420',
#   '5. volume': '772050'},
#  '2023-08-17 12:15:00': {'1. open': '174.7630',
#   '2. high': '175.0200',
#   '3. low': '174.6600',
#   '4. close': '174.9510',
#   '5. volume': '1348149'},
#  '2023-08-17 12:00:00': {'1. open': '174.6400',
#   '2. high': '174.8300',
#   '3. low': '174.4100',
#   '4. close': '174.7700',
#   '5. volume': '952729'},
#  '2023-08-17 11:45:00': {'1. open': '174.5200',
#   '2. high': '174.6700',
#   '3. low': '174.2700',
#   '4. close': '174.6300',
#   '5. volume': '1137723'},
#  '2023-08-17 11:30:00': {'1. open': '174.2700',
#   '2. high': '174.6700',
#   '3. low': '174.1000',
#   '4. close': '174.5250',
#   '5. volume': '1294643'},
#  '2023-08-17 11:15:00': {'1. open': '174.2200',
#   '2. high': '174.6500',
#   '3. low': '174.1400',
#   '4. close': '174.2700',
#   '5. volume': '1325668'},
#  '2023-08-17 11:00:00': {'1. open': '174.1000',
#   '2. high': '174.3600',
#   '3. low': '173.8300',
#   '4. close': '174.2150',
#   '5. volume': '1528559'}}

# %%
#store data into a DataFrame
df_apple1 = pd.DataFrame(apple1).transpose().reset_index()
df_apple1.head()
# Out:
#                  index   1. open   2. high    3. low  4. close 5. volume
# 0  2023-08-18 19:45:00  174.5400  174.7000  174.5000  174.7000      8691
# 1  2023-08-18 19:30:00  174.4700  174.5900  174.4700  174.5600     11647
# 2  2023-08-18 19:15:00  174.4800  174.5400  174.4700  174.4900     16188
# 3  2023-08-18 19:00:00  174.5500  174.5500  174.4700  174.4800      4915
# 4  2023-08-18 18:45:00  174.5500  174.5800  174.5000  174.5250      4517

# %%
#Bring in data in DataFrame format
ts2 = TimeSeries(key = API_key, output_format="pandas")

# %%
# display new intraday stock data
ts2.get_intraday("AAPL")
# Out:
# (                     1. open  2. high  3. low  4. close  5. volume
#  date
#  2023-08-18 19:45:00   174.54   174.70  174.50   174.700     8691.0
#  2023-08-18 19:30:00   174.47   174.59  174.47   174.560    11647.0
#  2023-08-18 19:15:00   174.48   174.54  174.47   174.490    16188.0
#  2023-08-18 19:00:00   174.55   174.55  174.47   174.480     4915.0
#  2023-08-18 18:45:00   174.55   174.58  174.50   174.525     4517.0
#  ...                      ...      ...     ...       ...        ...
#  2023-08-17 12:00:00   174.64   174.83  174.41   174.770   952729.0
#  2023-08-17 11:45:00   174.52   174.67  174.27   174.630  1137723.0
#  2023-08-17 11:30:00   174.27   174.67  174.10   174.525  1294643.0
#  2023-08-17 11:15:00   174.22   174.65  174.14   174.270  1325668.0
#  2023-08-17 11:00:00   174.10   174.36  173.83   174.215  1528559.0
#
#  [100 rows x 5 columns],
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-08-18 19:45:00',
#   '4. Interval': '15min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'})

# %%
#get full amount of intraday stock data for data and meta_data
df_apple2, meta_data = ts2.get_intraday("AAPL", outputsize="full")

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-08-18 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data with reset index
df_apple2.reset_index()
# Out:
#                     date  1. open  2. high  3. low  4. close  5. volume
# 0    2023-08-18 19:45:00  174.540  174.700  174.50   174.700     8691.0
# 1    2023-08-18 19:30:00  174.470  174.590  174.47   174.560    11647.0
# 2    2023-08-18 19:15:00  174.480  174.540  174.47   174.490    16188.0
# 3    2023-08-18 19:00:00  174.550  174.550  174.47   174.480     4915.0
# 4    2023-08-18 18:45:00  174.550  174.580  174.50   174.525     4517.0
# ...                  ...      ...      ...     ...       ...        ...
# 1339 2023-07-21 05:00:00  192.911  192.911  192.74   192.810     1897.0
# 1340 2023-07-21 04:45:00  192.940  193.011  192.80   192.910     4134.0
# 1341 2023-07-21 04:30:00  193.020  193.021  192.86   192.940     6885.0
# 1342 2023-07-21 04:15:00  192.751  193.001  192.74   193.000     6557.0
# 1343 2023-07-21 04:00:00  192.721  193.141  192.72   192.900    11057.0
#
# [1344 rows x 6 columns]
