# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&apikey=' + str(API_key) + '&datatype=csv'
r = requests.get(url).content
data = pd.read_csv (io.StringIO(r.decode('utf-8')))

print(data)
# Out:
#        timestamp    open    high      low   close     volume
# 0     2023-09-13  180.07  180.30  173.980  174.21  233591172
# 1     2023-09-08  188.28  189.98  173.540  178.18  305126712
# 2     2023-09-01  180.09  189.92  178.545  189.46  264199503
# 3     2023-08-25  175.07  181.55  173.735  178.61  247514268
# 4     2023-08-18  177.97  179.69  171.960  174.49  261498109
# ...          ...     ...     ...      ...     ...        ...
# 1240  1999-12-10  114.56  118.00   99.000  103.00   25152800
# 1241  1999-12-03   94.25  115.56   93.250  115.00   28046300
# 1242  1999-11-26   91.75   95.50   88.500   95.06    9757600
# 1243  1999-11-19   89.62   94.75   88.060   92.44   13711000
# 1244  1999-11-12   87.75   97.73   86.750   90.62   25776200
#
# [1245 rows x 6 columns]

# %%
#get head of data
data.head(10)
# Out:
#     timestamp    open    high      low   close     volume
# 0  2023-09-13  180.07  180.30  173.980  174.21  233591172
# 1  2023-09-08  188.28  189.98  173.540  178.18  305126712
# 2  2023-09-01  180.09  189.92  178.545  189.46  264199503
# 3  2023-08-25  175.07  181.55  173.735  178.61  247514268
# 4  2023-08-18  177.97  179.69  171.960  174.49  261498109
# 5  2023-08-11  182.13  183.13  176.550  177.79  332501087
# 6  2023-08-04  196.06  196.73  181.920  181.99  302694989
# 7  2023-07-28  193.41  197.20  192.250  195.83  226011789
# 8  2023-07-21  191.90  198.23  191.230  191.94  310914135
# 9  2023-07-14  189.26  191.70  186.600  190.69  250269110

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data = ts1.get_intraday('AAPL')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-09-13 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data
apple1
# Out:
# {'2023-09-13 19:45:00': {'1. open': '174.1000',
#   '2. high': '174.1500',
#   '3. low': '174.0800',
#   '4. close': '174.0900',
#   '5. volume': '25730'},
#  '2023-09-13 19:30:00': {'1. open': '174.1000',
#   '2. high': '174.1000',
#   '3. low': '174.0500',
#   '4. close': '174.1000',
#   '5. volume': '13348'},
#  '2023-09-13 19:15:00': {'1. open': '174.0900',
#   '2. high': '174.1500',
#   '3. low': '174.0500',
#   '4. close': '174.0900',
#   '5. volume': '10373'},
#  '2023-09-13 19:00:00': {'1. open': '174.0200',
#   '2. high': '174.1000',
#   '3. low': '174.0000',
#   '4. close': '174.0750',
#   '5. volume': '8819'},
#  '2023-09-13 18:45:00': {'1. open': '174.0600',
#   '2. high': '174.1300',
#   '3. low': '174.0000',
#   '4. close': '174.0300',
#   '5. volume': '11548'},
#  '2023-09-13 18:30:00': {'1. open': '174.0800',
#   '2. high': '174.1200',
#   '3. low': '174.0100',
#   '4. close': '174.0400',
#   '5. volume': '13572'},
#  '2023-09-13 18:15:00': {'1. open': '174.1300',
#   '2. high': '174.1400',
#   '3. low': '174.0000',
#   '4. close': '174.0750',
#   '5. volume': '18268'},
#  '2023-09-13 18:00:00': {'1. open': '174.1100',
#   '2. high': '174.1900',
#   '3. low': '174.0500',
#   '4. close': '174.1280',
#   '5. volume': '21030'},
#  '2023-09-13 17:45:00': {'1. open': '173.9600',
#   '2. high': '174.1600',
#   '3. low': '173.9000',
#   '4. close': '174.0600',
#   '5. volume': '50142'},
#  '2023-09-13 17:30:00': {'1. open': '173.9400',
#   '2. high': '173.9800',
#   '3. low': '173.8600',
#   '4. close': '173.9600',
#   '5. volume': '27835'},
#  '2023-09-13 17:15:00': {'1. open': '174.0000',
#   '2. high': '182.1440',
#   '3. low': '173.8000',
#   '4. close': '173.9300',
#   '5. volume': '55141'},
#  '2023-09-13 17:00:00': {'1. open': '173.9600',
#   '2. high': '175.7590',
#   '3. low': '162.7000',
#   '4. close': '174.0000',
#   '5. volume': '93062'},
#  '2023-09-13 16:45:00': {'1. open': '173.9600',
#   '2. high': '174.2100',
#   '3. low': '173.9100',
#   '4. close': '173.9600',
#   '5. volume': '312805'},
#  '2023-09-13 16:30:00': {'1. open': '174.0200',
#   '2. high': '174.2100',
#   '3. low': '173.8700',
#   '4. close': '173.9800',
#   '5. volume': '158112'},
#  '2023-09-13 16:15:00': {'1. open': '174.2000',
#   '2. high': '174.2300',
#   '3. low': '173.8500',
#   '4. close': '174.0500',
#   '5. volume': '613923'},
#  '2023-09-13 16:00:00': {'1. open': '174.2000',
#   '2. high': '179.6500',
#   '3. low': '173.9800',
#   '4. close': '174.2000',
#   '5. volume': '17137016'},
#  '2023-09-13 15:45:00': {'1. open': '174.8800',
#   '2. high': '175.0000',
#   '3. low': '173.9800',
#   '4. close': '174.2000',
#   '5. volume': '9162162'},
#  '2023-09-13 15:30:00': {'1. open': '175.0650',
#   '2. high': '175.1990',
#   '3. low': '174.8000',
#   '4. close': '174.8850',
#   '5. volume': '2072983'},
#  '2023-09-13 15:15:00': {'1. open': '174.5900',
#   '2. high': '175.1000',
#   '3. low': '174.5800',
#   '4. close': '175.0600',
#   '5. volume': '1781473'},
#  '2023-09-13 15:00:00': {'1. open': '174.7100',
#   '2. high': '174.7900',
#   '3. low': '174.5000',
#   '4. close': '174.6000',
#   '5. volume': '1657522'},
#  '2023-09-13 14:45:00': {'1. open': '174.9700',
#   '2. high': '175.1900',
#   '3. low': '174.3600',
#   '4. close': '174.7040',
#   '5. volume': '2517537'},
#  '2023-09-13 14:30:00': {'1. open': '174.8400',
#   '2. high': '175.1400',
#   '3. low': '174.5500',
#   '4. close': '174.9650',
#   '5. volume': '2278844'},
#  '2023-09-13 14:15:00': {'1. open': '174.9900',
#   '2. high': '174.9900',
#   '3. low': '174.7500',
#   '4. close': '174.8400',
#   '5. volume': '1798850'},
#  '2023-09-13 14:00:00': {'1. open': '175.1750',
#   '2. high': '175.2700',
#   '3. low': '174.9400',
#   '4. close': '174.9850',
#   '5. volume': '1492926'},
#  '2023-09-13 13:45:00': {'1. open': '175.4400',
#   '2. high': '175.5000',
#   '3. low': '175.0900',
#   '4. close': '175.1870',
#   '5. volume': '1341826'},
#  '2023-09-13 13:30:00': {'1. open': '175.3300',
#   '2. high': '175.4700',
#   '3. low': '175.2100',
#   '4. close': '175.4200',
#   '5. volume': '1231925'},
#  '2023-09-13 13:15:00': {'1. open': '175.5600',
#   '2. high': '175.7300',
#   '3. low': '175.3110',
#   '4. close': '175.3210',
#   '5. volume': '1473633'},
#  '2023-09-13 13:00:00': {'1. open': '175.5650',
#   '2. high': '175.7200',
#   '3. low': '175.3900',
#   '4. close': '175.5540',
#   '5. volume': '1396113'},
#  '2023-09-13 12:45:00': {'1. open': '175.4100',
#   '2. high': '175.7200',
#   '3. low': '175.2600',
#   '4. close': '175.5650',
#   '5. volume': '1504190'},
#  '2023-09-13 12:30:00': {'1. open': '175.7050',
#   '2. high': '175.7700',
#   '3. low': '175.3700',
#   '4. close': '175.4000',
#   '5. volume': '1274143'},
#  '2023-09-13 12:15:00': {'1. open': '175.7300',
#   '2. high': '176.0000',
#   '3. low': '175.6600',
#   '4. close': '175.7300',
#   '5. volume': '1569117'},
#  '2023-09-13 12:00:00': {'1. open': '175.7400',
#   '2. high': '176.2300',
#   '3. low': '175.6900',
#   '4. close': '175.7250',
#   '5. volume': '2567259'},
#  '2023-09-13 11:45:00': {'1. open': '175.1750',
#   '2. high': '175.7700',
#   '3. low': '175.1300',
#   '4. close': '175.7320',
#   '5. volume': '2117928'},
#  '2023-09-13 11:30:00': {'1. open': '175.2000',
#   '2. high': '175.4500',
#   '3. low': '174.8700',
#   '4. close': '175.1750',
#   '5. volume': '1855534'},
#  '2023-09-13 11:15:00': {'1. open': '174.8200',
#   '2. high': '175.3000',
#   '3. low': '174.7600',
#   '4. close': '175.2160',
#   '5. volume': '2195108'},
#  '2023-09-13 11:00:00': {'1. open': '174.7400',
#   '2. high': '175.2200',
#   '3. low': '174.6700',
#   '4. close': '174.8260',
#   '5. volume': '4774101'},
#  '2023-09-13 10:45:00': {'1. open': '175.0900',
#   '2. high': '175.1220',
#   '3. low': '174.7000',
#   '4. close': '174.7350',
#   '5. volume': '2305726'},
#  '2023-09-13 10:30:00': {'1. open': '175.1900',
#   '2. high': '175.5000',
#   '3. low': '175.0000',
#   '4. close': '175.0900',
#   '5. volume': '2730362'},
#  '2023-09-13 10:15:00': {'1. open': '174.6700',
#   '2. high': '175.2900',
#   '3. low': '174.0700',
#   '4. close': '175.1900',
#   '5. volume': '4285607'},
#  '2023-09-13 10:00:00': {'1. open': '175.8150',
#   '2. high': '175.9000',
#   '3. low': '174.6600',
#   '4. close': '174.6800',
#   '5. volume': '3103491'},
#  '2023-09-13 09:45:00': {'1. open': '175.8400',
#   '2. high': '175.9500',
#   '3. low': '174.5900',
#   '4. close': '175.8080',
#   '5. volume': '5431431'},
#  '2023-09-13 09:30:00': {'1. open': '176.5100',
#   '2. high': '177.3000',
#   '3. low': '175.3300',
#   '4. close': '175.8300',
#   '5. volume': '6599243'},
#  '2023-09-13 09:15:00': {'1. open': '177.1000',
#   '2. high': '177.3800',
#   '3. low': '176.2000',
#   '4. close': '176.5000',
#   '5. volume': '310580'},
#  '2023-09-13 09:00:00': {'1. open': '177.1300',
#   '2. high': '177.4980',
#   '3. low': '176.3000',
#   '4. close': '177.0900',
#   '5. volume': '246784'},
#  '2023-09-13 08:45:00': {'1. open': '176.6900',
#   '2. high': '177.4000',
#   '3. low': '176.4400',
#   '4. close': '177.1300',
#   '5. volume': '235402'},
#  '2023-09-13 08:30:00': {'1. open': '176.6600',
#   '2. high': '177.1100',
#   '3. low': '175.2800',
#   '4. close': '176.7000',
#   '5. volume': '537502'},
#  '2023-09-13 08:15:00': {'1. open': '176.7800',
#   '2. high': '176.9000',
#   '3. low': '176.3350',
#   '4. close': '176.4000',
#   '5. volume': '129318'},
#  '2023-09-13 08:00:00': {'1. open': '175.4600',
#   '2. high': '177.0000',
#   '3. low': '175.1850',
#   '4. close': '176.7450',
#   '5. volume': '285887'},
#  '2023-09-13 07:45:00': {'1. open': '176.2800',
#   '2. high': '176.7500',
#   '3. low': '176.2700',
#   '4. close': '176.6600',
#   '5. volume': '67905'},
#  '2023-09-13 07:30:00': {'1. open': '175.9300',
#   '2. high': '176.3500',
#   '3. low': '175.8900',
#   '4. close': '176.2500',
#   '5. volume': '67047'},
#  '2023-09-13 07:15:00': {'1. open': '175.4800',
#   '2. high': '176.2900',
#   '3. low': '175.3700',
#   '4. close': '175.9400',
#   '5. volume': '72462'},
#  '2023-09-13 07:00:00': {'1. open': '175.5400',
#   '2. high': '175.6200',
#   '3. low': '175.2100',
#   '4. close': '175.4700',
#   '5. volume': '69043'},
#  '2023-09-13 06:45:00': {'1. open': '175.5000',
#   '2. high': '175.5500',
#   '3. low': '175.4400',
#   '4. close': '175.5500',
#   '5. volume': '18132'},
#  '2023-09-13 06:30:00': {'1. open': '175.3800',
#   '2. high': '175.5900',
#   '3. low': '175.2800',
#   '4. close': '175.5000',
#   '5. volume': '26596'},
#  '2023-09-13 06:15:00': {'1. open': '175.4000',
#   '2. high': '175.5200',
#   '3. low': '175.2400',
#   '4. close': '175.3600',
#   '5. volume': '13382'},
#  '2023-09-13 06:00:00': {'1. open': '175.5400',
#   '2. high': '175.5400',
#   '3. low': '175.1900',
#   '4. close': '175.4000',
#   '5. volume': '25406'},
#  '2023-09-13 05:45:00': {'1. open': '175.5500',
#   '2. high': '175.8500',
#   '3. low': '175.4300',
#   '4. close': '175.5400',
#   '5. volume': '17241'},
#  '2023-09-13 05:30:00': {'1. open': '175.8700',
#   '2. high': '175.8700',
#   '3. low': '175.5900',
#   '4. close': '175.6000',
#   '5. volume': '8213'},
#  '2023-09-13 05:15:00': {'1. open': '175.6500',
#   '2. high': '175.9100',
#   '3. low': '175.6300',
#   '4. close': '175.8500',
#   '5. volume': '18594'},
#  '2023-09-13 05:00:00': {'1. open': '175.9100',
#   '2. high': '175.9200',
#   '3. low': '175.4000',
#   '4. close': '175.6500',
#   '5. volume': '31718'},
#  '2023-09-13 04:45:00': {'1. open': '176.0400',
#   '2. high': '176.2400',
#   '3. low': '175.8100',
#   '4. close': '175.8100',
#   '5. volume': '42808'},
#  '2023-09-13 04:30:00': {'1. open': '176.6300',
#   '2. high': '176.9000',
#   '3. low': '175.9300',
#   '4. close': '176.0400',
#   '5. volume': '45996'},
#  '2023-09-13 04:15:00': {'1. open': '176.5800',
#   '2. high': '176.7200',
#   '3. low': '176.3500',
#   '4. close': '176.6500',
#   '5. volume': '20493'},
#  '2023-09-13 04:00:00': {'1. open': '176.3500',
#   '2. high': '177.0000',
#   '3. low': '176.0600',
#   '4. close': '176.5400',
#   '5. volume': '56514'},
#  '2023-09-12 19:45:00': {'1. open': '176.3850',
#   '2. high': '176.4500',
#   '3. low': '176.3100',
#   '4. close': '176.3500',
#   '5. volume': '21005'},
#  '2023-09-12 19:30:00': {'1. open': '176.3700',
#   '2. high': '176.3900',
#   '3. low': '176.3400',
#   '4. close': '176.3900',
#   '5. volume': '12749'},
#  '2023-09-12 19:15:00': {'1. open': '176.3700',
#   '2. high': '176.3800',
#   '3. low': '176.3400',
#   '4. close': '176.3600',
#   '5. volume': '8811'},
#  '2023-09-12 19:00:00': {'1. open': '176.3900',
#   '2. high': '176.4000',
#   '3. low': '176.3500',
#   '4. close': '176.3800',
#   '5. volume': '14772'},
#  '2023-09-12 18:45:00': {'1. open': '176.4000',
#   '2. high': '176.4400',
#   '3. low': '176.3700',
#   '4. close': '176.3800',
#   '5. volume': '7702'},
#  '2023-09-12 18:30:00': {'1. open': '176.4200',
#   '2. high': '176.4500',
#   '3. low': '176.3400',
#   '4. close': '176.4200',
#   '5. volume': '15421'},
#  '2023-09-12 18:15:00': {'1. open': '176.4200',
#   '2. high': '176.4500',
#   '3. low': '176.3700',
#   '4. close': '176.4400',
#   '5. volume': '11581'},
#  '2023-09-12 18:00:00': {'1. open': '176.4700',
#   '2. high': '176.4800',
#   '3. low': '176.3700',
#   '4. close': '176.4000',
#   '5. volume': '11637'},
#  '2023-09-12 17:45:00': {'1. open': '176.4100',
#   '2. high': '176.4900',
#   '3. low': '176.4000',
#   '4. close': '176.4400',
#   '5. volume': '17999'},
#  '2023-09-12 17:30:00': {'1. open': '176.5000',
#   '2. high': '176.5200',
#   '3. low': '176.3500',
#   '4. close': '176.4200',
#   '5. volume': '26547'},
#  '2023-09-12 17:15:00': {'1. open': '176.4800',
#   '2. high': '176.5400',
#   '3. low': '164.1860',
#   '4. close': '176.4800',
#   '5. volume': '26366'},
#  '2023-09-12 17:00:00': {'1. open': '176.4000',
#   '2. high': '176.5900',
#   '3. low': '168.3280',
#   '4. close': '176.4700',
#   '5. volume': '136782'},
#  '2023-09-12 16:45:00': {'1. open': '176.3600',
#   '2. high': '176.4700',
#   '3. low': '176.3400',
#   '4. close': '176.3900',
#   '5. volume': '36616'},
#  '2023-09-12 16:30:00': {'1. open': '176.3380',
#   '2. high': '176.4500',
#   '3. low': '175.5800',
#   '4. close': '176.3800',
#   '5. volume': '102243'},
#  '2023-09-12 16:15:00': {'1. open': '176.3000',
#   '2. high': '176.4800',
#   '3. low': '176.2100',
#   '4. close': '176.3400',
#   '5. volume': '144219'},
#  '2023-09-12 16:00:00': {'1. open': '176.3100',
#   '2. high': '176.8300',
#   '3. low': '176.2100',
#   '4. close': '176.4800',
#   '5. volume': '12989885'},
#  '2023-09-12 15:45:00': {'1. open': '175.9500',
#   '2. high': '176.4600',
#   '3. low': '175.7110',
#   '4. close': '176.3100',
#   '5. volume': '6355936'},
#  '2023-09-12 15:30:00': {'1. open': '175.7200',
#   '2. high': '175.9500',
#   '3. low': '175.4900',
#   '4. close': '175.9400',
#   '5. volume': '3066840'},
#  '2023-09-12 15:15:00': {'1. open': '175.0900',
#   '2. high': '175.7800',
#   '3. low': '175.0000',
#   '4. close': '175.7200',
#   '5. volume': '2398734'},
#  '2023-09-12 15:00:00': {'1. open': '175.3300',
#   '2. high': '175.4800',
#   '3. low': '175.0600',
#   '4. close': '175.1000',
#   '5. volume': '3573252'},
#  '2023-09-12 14:45:00': {'1. open': '176.0300',
#   '2. high': '176.2000',
#   '3. low': '175.1400',
#   '4. close': '175.3290',
#   '5. volume': '2807287'},
#  '2023-09-12 14:30:00': {'1. open': '176.1100',
#   '2. high': '176.7500',
#   '3. low': '175.6500',
#   '4. close': '176.0400',
#   '5. volume': '3729631'},
#  '2023-09-12 14:15:00': {'1. open': '176.2500',
#   '2. high': '176.4610',
#   '3. low': '174.8200',
#   '4. close': '176.1000',
#   '5. volume': '8535678'},
#  '2023-09-12 14:00:00': {'1. open': '176.3900',
#   '2. high': '176.7800',
#   '3. low': '176.0100',
#   '4. close': '176.2500',
#   '5. volume': '3034825'},
#  '2023-09-12 13:45:00': {'1. open': '176.7900',
#   '2. high': '177.0490',
#   '3. low': '175.4500',
#   '4. close': '176.4000',
#   '5. volume': '6234945'},
#  '2023-09-12 13:30:00': {'1. open': '177.5700',
#   '2. high': '177.8500',
#   '3. low': '176.6600',
#   '4. close': '176.7970',
#   '5. volume': '2844398'},
#  '2023-09-12 13:15:00': {'1. open': '176.9560',
#   '2. high': '178.1600',
#   '3. low': '176.9400',
#   '4. close': '177.5700',
#   '5. volume': '2453766'},
#  '2023-09-12 13:00:00': {'1. open': '176.9700',
#   '2. high': '177.2400',
#   '3. low': '176.6400',
#   '4. close': '176.9500',
#   '5. volume': '1844329'},
#  '2023-09-12 12:45:00': {'1. open': '177.0400',
#   '2. high': '177.2700',
#   '3. low': '176.8600',
#   '4. close': '176.9690',
#   '5. volume': '1562016'},
#  '2023-09-12 12:30:00': {'1. open': '176.6100',
#   '2. high': '177.1000',
#   '3. low': '176.3950',
#   '4. close': '177.0400',
#   '5. volume': '1578837'},
#  '2023-09-12 12:15:00': {'1. open': '177.0200',
#   '2. high': '177.0400',
#   '3. low': '176.5200',
#   '4. close': '176.6050',
#   '5. volume': '1116042'},
#  '2023-09-12 12:00:00': {'1. open': '176.6850',
#   '2. high': '177.1800',
#   '3. low': '176.6400',
#   '4. close': '177.0150',
#   '5. volume': '2417086'},
#  '2023-09-12 11:45:00': {'1. open': '176.9800',
#   '2. high': '177.1200',
#   '3. low': '176.6800',
#   '4. close': '176.6800',
#   '5. volume': '1728554'},
#  '2023-09-12 11:30:00': {'1. open': '176.7120',
#   '2. high': '177.0300',
#   '3. low': '176.7120',
#   '4. close': '176.9820',
#   '5. volume': '1912246'},
#  '2023-09-12 11:15:00': {'1. open': '176.4000',
#   '2. high': '176.7200',
#   '3. low': '176.2700',
#   '4. close': '176.7000',
#   '5. volume': '1456654'},
#  '2023-09-12 11:00:00': {'1. open': '176.3450',
#   '2. high': '176.6760',
#   '3. low': '176.2500',
#   '4. close': '176.4050',
#   '5. volume': '2138270'}}

# %%
#store data into a DataFrame
df_apple1 = pd.DataFrame(apple1).transpose().reset_index()
df_apple1.head()
# Out:
#                  index   1. open   2. high    3. low  4. close 5. volume
# 0  2023-09-13 19:45:00  174.1000  174.1500  174.0800  174.0900     25730
# 1  2023-09-13 19:30:00  174.1000  174.1000  174.0500  174.1000     13348
# 2  2023-09-13 19:15:00  174.0900  174.1500  174.0500  174.0900     10373
# 3  2023-09-13 19:00:00  174.0200  174.1000  174.0000  174.0750      8819
# 4  2023-09-13 18:45:00  174.0600  174.1300  174.0000  174.0300     11548

# %%
#Bring in data in DataFrame format
ts2 = TimeSeries(key=API_key, output_format='pandas')

# %%
# display new intraday stock data
ts2.get_intraday('AAPL')
# Out:
# (                     1. open  2. high   3. low  4. close  5. volume
#  date
#  2023-09-13 19:45:00  174.100  174.150  174.080   174.090    25730.0
#  2023-09-13 19:30:00  174.100  174.100  174.050   174.100    13348.0
#  2023-09-13 19:15:00  174.090  174.150  174.050   174.090    10373.0
#  2023-09-13 19:00:00  174.020  174.100  174.000   174.075     8819.0
#  2023-09-13 18:45:00  174.060  174.130  174.000   174.030    11548.0
#  ...                      ...      ...      ...       ...        ...
#  2023-09-12 12:00:00  176.685  177.180  176.640   177.015  2417086.0
#  2023-09-12 11:45:00  176.980  177.120  176.680   176.680  1728554.0
#  2023-09-12 11:30:00  176.712  177.030  176.712   176.982  1912246.0
#  2023-09-12 11:15:00  176.400  176.720  176.270   176.700  1456654.0
#  2023-09-12 11:00:00  176.345  176.676  176.250   176.405  2138270.0
#
#  [100 rows x 5 columns],
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-09-13 19:45:00',
#   '4. Interval': '15min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'})

# %%
#get full amount of intraday stock data for data and meta_data
df_apple2, meta_data = ts2.get_intraday('AAPL', outputsize='full')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-09-13 19:45:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data with reset index
df_apple2.reset_index()
# Out:
#                    date  1. open  2. high  3. low  4. close  5. volume
# 0   2023-09-13 19:45:00   174.10   174.15  174.08   174.090    25730.0
# 1   2023-09-13 19:30:00   174.10   174.10  174.05   174.100    13348.0
# 2   2023-09-13 19:15:00   174.09   174.15  174.05   174.090    10373.0
# 3   2023-09-13 19:00:00   174.02   174.10  174.00   174.075     8819.0
# 4   2023-09-13 18:45:00   174.06   174.13  174.00   174.030    11548.0
# ..                  ...      ...      ...     ...       ...        ...
# 955 2023-08-23 05:00:00   178.30   178.43  178.29   178.330     5857.0
# 956 2023-08-23 04:45:00   178.25   178.34  178.20   178.320     4394.0
# 957 2023-08-23 04:30:00   178.21   178.31  178.19   178.280     8577.0
# 958 2023-08-23 04:15:00   178.27   178.40  178.19   178.200     5285.0
# 959 2023-08-23 04:00:00   177.67   178.30  177.67   178.270     9675.0
#
# [960 rows x 6 columns]
