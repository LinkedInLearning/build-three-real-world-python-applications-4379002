# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()
API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&apikey=' + str(API_key) + '&datatype=csv'
r = requests.get(url).content
data = pd.read_csv(io.StringIO(r.decode('utf-8')))

print(data)
# Out:
#        timestamp    open    high     low   close     volume
# 0     2023-04-21  165.09  168.16  164.03  165.02  249150510
# 1     2023-04-14  161.42  166.32  159.78  165.21  263326290
# 2     2023-04-06  164.27  166.84  161.80  164.66  200156349
# 3     2023-03-31  159.94  165.00  155.98  164.90  267939590
# 4     2023-03-24  155.07  162.14  154.15  160.25  350159914
# ...          ...     ...     ...     ...     ...        ...
# 1219  1999-12-10  114.56  118.00   99.00  103.00   25152800
# 1220  1999-12-03   94.25  115.56   93.25  115.00   28046300
# 1221  1999-11-26   91.75   95.50   88.50   95.06    9757600
# 1222  1999-11-19   89.62   94.75   88.06   92.44   13711000
# 1223  1999-11-12   87.75   97.73   86.75   90.62   25776200
#
# [1224 rows x 6 columns]

# %%
#get head of data
data.head(10)
# Out:
#     timestamp     open    high       low   close     volume
# 0  2023-04-21  165.090  168.16  164.0300  165.02  249150510
# 1  2023-04-14  161.420  166.32  159.7800  165.21  263326290
# 2  2023-04-06  164.270  166.84  161.8000  164.66  200156349
# 3  2023-03-31  159.940  165.00  155.9800  164.90  267939590
# 4  2023-03-24  155.070  162.14  154.1500  160.25  350159914
# 5  2023-03-17  147.805  156.74  147.7000  155.00  410519933
# 6  2023-03-10  153.785  156.30  147.6096  148.50  313350829
# 7  2023-03-03  147.710  151.11  143.9000  151.03  274036517
# 8  2023-02-24  150.200  151.30  145.7202  146.71  213742390
# 9  2023-02-17  150.952  156.33  150.8500  152.55  316887898

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data = ts1.get_intraday('AAPL')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-04-21 20:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data
apple1
# Out:
# {'2023-04-21 20:00:00': {'1. open': '164.9200',
#   '2. high': '165.0000',
#   '3. low': '164.9200',
#   '4. close': '164.9201',
#   '5. volume': '5051'},
#  '2023-04-21 19:45:00': {'1. open': '164.9400',
#   '2. high': '164.9400',
#   '3. low': '164.9000',
#   '4. close': '164.9000',
#   '5. volume': '3592'},
#  '2023-04-21 19:30:00': {'1. open': '164.9400',
#   '2. high': '164.9400',
#   '3. low': '164.9400',
#   '4. close': '164.9400',
#   '5. volume': '246'},
#  '2023-04-21 19:15:00': {'1. open': '164.9000',
#   '2. high': '164.9600',
#   '3. low': '164.9000',
#   '4. close': '164.9600',
#   '5. volume': '1150'},
#  '2023-04-21 19:00:00': {'1. open': '164.9600',
#   '2. high': '164.9600',
#   '3. low': '164.9100',
#   '4. close': '164.9100',
#   '5. volume': '5659'},
#  '2023-04-21 18:45:00': {'1. open': '164.9500',
#   '2. high': '164.9800',
#   '3. low': '164.9500',
#   '4. close': '164.9800',
#   '5. volume': '3744'},
#  '2023-04-21 18:30:00': {'1. open': '164.9600',
#   '2. high': '164.9600',
#   '3. low': '164.9500',
#   '4. close': '164.9500',
#   '5. volume': '3284'},
#  '2023-04-21 18:15:00': {'1. open': '164.9501',
#   '2. high': '165.0000',
#   '3. low': '164.9500',
#   '4. close': '164.9500',
#   '5. volume': '2601'},
#  '2023-04-21 18:00:00': {'1. open': '164.9715',
#   '2. high': '165.0000',
#   '3. low': '164.9500',
#   '4. close': '164.9500',
#   '5. volume': '3277'},
#  '2023-04-21 17:45:00': {'1. open': '164.9700',
#   '2. high': '165.0200',
#   '3. low': '164.9700',
#   '4. close': '165.0000',
#   '5. volume': '280403'},
#  '2023-04-21 17:30:00': {'1. open': '164.9900',
#   '2. high': '165.0000',
#   '3. low': '164.9900',
#   '4. close': '164.9900',
#   '5. volume': '2788'},
#  '2023-04-21 17:15:00': {'1. open': '164.9800',
#   '2. high': '165.0000',
#   '3. low': '164.9800',
#   '4. close': '164.9900',
#   '5. volume': '1152895'},
#  '2023-04-21 17:00:00': {'1. open': '164.9800',
#   '2. high': '164.9900',
#   '3. low': '164.9800',
#   '4. close': '164.9800',
#   '5. volume': '11958'},
#  '2023-04-21 16:45:00': {'1. open': '165.0000',
#   '2. high': '165.0200',
#   '3. low': '164.9800',
#   '4. close': '164.9801',
#   '5. volume': '24310'},
#  '2023-04-21 16:30:00': {'1. open': '164.9800',
#   '2. high': '165.0300',
#   '3. low': '164.9700',
#   '4. close': '165.0000',
#   '5. volume': '60469'},
#  '2023-04-21 16:15:00': {'1. open': '165.0200',
#   '2. high': '165.0700',
#   '3. low': '164.9700',
#   '4. close': '164.9700',
#   '5. volume': '1186644'},
#  '2023-04-21 16:00:00': {'1. open': '164.8050',
#   '2. high': '165.0600',
#   '3. low': '164.7650',
#   '4. close': '165.0200',
#   '5. volume': '3400815'},
#  '2023-04-21 15:45:00': {'1. open': '164.9550',
#   '2. high': '165.0500',
#   '3. low': '164.6900',
#   '4. close': '164.8050',
#   '5. volume': '1841172'},
#  '2023-04-21 15:30:00': {'1. open': '164.7400',
#   '2. high': '164.9800',
#   '3. low': '164.7150',
#   '4. close': '164.9575',
#   '5. volume': '2314918'},
#  '2023-04-21 15:15:00': {'1. open': '165.0328',
#   '2. high': '165.0650',
#   '3. low': '164.7200',
#   '4. close': '164.7500',
#   '5. volume': '1252064'},
#  '2023-04-21 15:00:00': {'1. open': '164.9914',
#   '2. high': '165.0850',
#   '3. low': '164.8800',
#   '4. close': '165.0350',
#   '5. volume': '992606'},
#  '2023-04-21 14:45:00': {'1. open': '165.2785',
#   '2. high': '165.3600',
#   '3. low': '164.9348',
#   '4. close': '164.9923',
#   '5. volume': '1326042'},
#  '2023-04-21 14:30:00': {'1. open': '165.2000',
#   '2. high': '165.3650',
#   '3. low': '165.0340',
#   '4. close': '165.2750',
#   '5. volume': '1381159'},
#  '2023-04-21 14:15:00': {'1. open': '165.0750',
#   '2. high': '165.2500',
#   '3. low': '165.0200',
#   '4. close': '165.1825',
#   '5. volume': '1210931'},
#  '2023-04-21 14:00:00': {'1. open': '164.9900',
#   '2. high': '165.1000',
#   '3. low': '164.8900',
#   '4. close': '165.0750',
#   '5. volume': '1012069'},
#  '2023-04-21 13:45:00': {'1. open': '164.7999',
#   '2. high': '165.0550',
#   '3. low': '164.7100',
#   '4. close': '164.9934',
#   '5. volume': '1290441'},
#  '2023-04-21 13:30:00': {'1. open': '165.0533',
#   '2. high': '165.1409',
#   '3. low': '164.6800',
#   '4. close': '164.7975',
#   '5. volume': '1087422'},
#  '2023-04-21 13:15:00': {'1. open': '164.8950',
#   '2. high': '165.2100',
#   '3. low': '164.8500',
#   '4. close': '165.0507',
#   '5. volume': '1040969'},
#  '2023-04-21 13:00:00': {'1. open': '164.7900',
#   '2. high': '165.0600',
#   '3. low': '164.7550',
#   '4. close': '164.9000',
#   '5. volume': '847577'},
#  '2023-04-21 12:45:00': {'1. open': '164.9250',
#   '2. high': '165.0200',
#   '3. low': '164.7450',
#   '4. close': '164.7900',
#   '5. volume': '900447'},
#  '2023-04-21 12:30:00': {'1. open': '164.9900',
#   '2. high': '165.1800',
#   '3. low': '164.8802',
#   '4. close': '164.9291',
#   '5. volume': '1068905'},
#  '2023-04-21 12:15:00': {'1. open': '165.2200',
#   '2. high': '165.2400',
#   '3. low': '164.8483',
#   '4. close': '164.9826',
#   '5. volume': '951620'},
#  '2023-04-21 12:00:00': {'1. open': '165.1500',
#   '2. high': '165.2400',
#   '3. low': '164.8100',
#   '4. close': '165.2200',
#   '5. volume': '1123684'},
#  '2023-04-21 11:45:00': {'1. open': '165.1000',
#   '2. high': '165.4200',
#   '3. low': '164.9628',
#   '4. close': '165.1499',
#   '5. volume': '1347734'},
#  '2023-04-21 11:30:00': {'1. open': '164.8950',
#   '2. high': '165.1500',
#   '3. low': '164.7100',
#   '4. close': '165.0900',
#   '5. volume': '1384548'},
#  '2023-04-21 11:15:00': {'1. open': '165.0200',
#   '2. high': '165.3250',
#   '3. low': '164.7900',
#   '4. close': '164.9000',
#   '5. volume': '1758084'},
#  '2023-04-21 11:00:00': {'1. open': '164.8500',
#   '2. high': '165.0350',
#   '3. low': '164.4900',
#   '4. close': '165.0100',
#   '5. volume': '2444214'},
#  '2023-04-21 10:45:00': {'1. open': '165.3700',
#   '2. high': '165.4600',
#   '3. low': '164.8000',
#   '4. close': '164.8501',
#   '5. volume': '1890896'},
#  '2023-04-21 10:30:00': {'1. open': '165.0450',
#   '2. high': '165.6800',
#   '3. low': '165.0426',
#   '4. close': '165.3798',
#   '5. volume': '2102404'},
#  '2023-04-21 10:15:00': {'1. open': '164.8950',
#   '2. high': '165.1750',
#   '3. low': '164.7200',
#   '4. close': '165.0400',
#   '5. volume': '2763560'},
#  '2023-04-21 10:00:00': {'1. open': '165.8400',
#   '2. high': '165.9399',
#   '3. low': '164.8700',
#   '4. close': '164.9000',
#   '5. volume': '3311129'},
#  '2023-04-21 09:45:00': {'1. open': '165.0500',
#   '2. high': '166.4521',
#   '3. low': '164.6700',
#   '4. close': '165.8300',
#   '5. volume': '8054313'},
#  '2023-04-21 09:30:00': {'1. open': '164.6900',
#   '2. high': '165.4000',
#   '3. low': '164.5800',
#   '4. close': '165.0500',
#   '5. volume': '432448'},
#  '2023-04-21 09:15:00': {'1. open': '164.6200',
#   '2. high': '164.8400',
#   '3. low': '164.4100',
#   '4. close': '164.6900',
#   '5. volume': '145623'},
#  '2023-04-21 09:00:00': {'1. open': '164.4500',
#   '2. high': '164.6900',
#   '3. low': '164.3000',
#   '4. close': '164.6200',
#   '5. volume': '94558'},
#  '2023-04-21 08:45:00': {'1. open': '164.6600',
#   '2. high': '164.6800',
#   '3. low': '164.2100',
#   '4. close': '164.3220',
#   '5. volume': '126312'},
#  '2023-04-21 08:30:00': {'1. open': '164.3500',
#   '2. high': '164.7489',
#   '3. low': '164.1000',
#   '4. close': '164.7489',
#   '5. volume': '114951'},
#  '2023-04-21 08:15:00': {'1. open': '164.3500',
#   '2. high': '166.4400',
#   '3. low': '163.8000',
#   '4. close': '164.3500',
#   '5. volume': '172236'},
#  '2023-04-21 08:00:00': {'1. open': '164.1600',
#   '2. high': '164.2500',
#   '3. low': '163.8900',
#   '4. close': '164.0000',
#   '5. volume': '85588'},
#  '2023-04-21 07:45:00': {'1. open': '164.3300',
#   '2. high': '164.4000',
#   '3. low': '164.0500',
#   '4. close': '164.1800',
#   '5. volume': '100290'},
#  '2023-04-21 07:30:00': {'1. open': '164.2400',
#   '2. high': '164.4900',
#   '3. low': '164.2000',
#   '4. close': '164.2700',
#   '5. volume': '53285'},
#  '2023-04-21 07:15:00': {'1. open': '163.9700',
#   '2. high': '164.4900',
#   '3. low': '163.9700',
#   '4. close': '164.2000',
#   '5. volume': '143971'},
#  '2023-04-21 07:00:00': {'1. open': '163.7000',
#   '2. high': '164.2300',
#   '3. low': '163.6600',
#   '4. close': '163.7700',
#   '5. volume': '64523'},
#  '2023-04-21 06:45:00': {'1. open': '166.3800',
#   '2. high': '166.3800',
#   '3. low': '162.9900',
#   '4. close': '163.7100',
#   '5. volume': '204757'},
#  '2023-04-21 06:30:00': {'1. open': '166.4700',
#   '2. high': '166.4700',
#   '3. low': '166.3700',
#   '4. close': '166.3800',
#   '5. volume': '1283'},
#  '2023-04-21 06:15:00': {'1. open': '166.5700',
#   '2. high': '166.5700',
#   '3. low': '166.5500',
#   '4. close': '166.5500',
#   '5. volume': '702'},
#  '2023-04-21 06:00:00': {'1. open': '166.6100',
#   '2. high': '166.6100',
#   '3. low': '166.6100',
#   '4. close': '166.6100',
#   '5. volume': '813'},
#  '2023-04-21 05:45:00': {'1. open': '166.5500',
#   '2. high': '166.6600',
#   '3. low': '166.5200',
#   '4. close': '166.6600',
#   '5. volume': '2197'},
#  '2023-04-21 05:30:00': {'1. open': '166.5600',
#   '2. high': '166.5600',
#   '3. low': '166.5600',
#   '4. close': '166.5600',
#   '5. volume': '412'},
#  '2023-04-21 05:15:00': {'1. open': '166.6000',
#   '2. high': '166.6000',
#   '3. low': '166.5000',
#   '4. close': '166.5000',
#   '5. volume': '1122'},
#  '2023-04-21 05:00:00': {'1. open': '166.5000',
#   '2. high': '166.6000',
#   '3. low': '166.5000',
#   '4. close': '166.5800',
#   '5. volume': '2547'},
#  '2023-04-21 04:45:00': {'1. open': '166.3200',
#   '2. high': '166.4000',
#   '3. low': '166.3200',
#   '4. close': '166.4000',
#   '5. volume': '1733'},
#  '2023-04-21 04:30:00': {'1. open': '166.4300',
#   '2. high': '166.4500',
#   '3. low': '166.3300',
#   '4. close': '166.3400',
#   '5. volume': '2184'},
#  '2023-04-21 04:15:00': {'1. open': '166.6800',
#   '2. high': '166.6800',
#   '3. low': '166.5000',
#   '4. close': '166.5600',
#   '5. volume': '7207'},
#  '2023-04-20 20:00:00': {'1. open': '166.7600',
#   '2. high': '166.9800',
#   '3. low': '166.7000',
#   '4. close': '166.9800',
#   '5. volume': '17199'},
#  '2023-04-20 19:45:00': {'1. open': '166.8600',
#   '2. high': '166.9000',
#   '3. low': '166.7300',
#   '4. close': '166.7500',
#   '5. volume': '13753'},
#  '2023-04-20 19:30:00': {'1. open': '166.7800',
#   '2. high': '166.8600',
#   '3. low': '166.7300',
#   '4. close': '166.8600',
#   '5. volume': '7145'},
#  '2023-04-20 19:15:00': {'1. open': '166.7400',
#   '2. high': '166.8500',
#   '3. low': '166.7200',
#   '4. close': '166.7200',
#   '5. volume': '14237'},
#  '2023-04-20 19:00:00': {'1. open': '166.7000',
#   '2. high': '166.7400',
#   '3. low': '166.7000',
#   '4. close': '166.7200',
#   '5. volume': '16908'},
#  '2023-04-20 18:45:00': {'1. open': '166.7000',
#   '2. high': '166.7700',
#   '3. low': '166.7000',
#   '4. close': '166.7100',
#   '5. volume': '14194'},
#  '2023-04-20 18:30:00': {'1. open': '166.6800',
#   '2. high': '166.7000',
#   '3. low': '166.6400',
#   '4. close': '166.6700',
#   '5. volume': '7548'},
#  '2023-04-20 18:15:00': {'1. open': '166.6600',
#   '2. high': '166.7400',
#   '3. low': '166.6100',
#   '4. close': '166.7400',
#   '5. volume': '28574'},
#  '2023-04-20 18:00:00': {'1. open': '166.6200',
#   '2. high': '166.6900',
#   '3. low': '166.6200',
#   '4. close': '166.6600',
#   '5. volume': '1825'},
#  '2023-04-20 17:45:00': {'1. open': '166.6200',
#   '2. high': '166.6600',
#   '3. low': '166.6200',
#   '4. close': '166.6600',
#   '5. volume': '1847'},
#  '2023-04-20 17:30:00': {'1. open': '166.6200',
#   '2. high': '166.6500',
#   '3. low': '166.6200',
#   '4. close': '166.6300',
#   '5. volume': '1138'},
#  '2023-04-20 17:15:00': {'1. open': '166.6110',
#   '2. high': '166.6500',
#   '3. low': '166.6100',
#   '4. close': '166.6500',
#   '5. volume': '40910'},
#  '2023-04-20 17:00:00': {'1. open': '166.6500',
#   '2. high': '166.6773',
#   '3. low': '166.5800',
#   '4. close': '166.6300',
#   '5. volume': '23396'},
#  '2023-04-20 16:45:00': {'1. open': '166.7300',
#   '2. high': '166.7600',
#   '3. low': '166.6500',
#   '4. close': '166.6500',
#   '5. volume': '39138'},
#  '2023-04-20 16:30:00': {'1. open': '166.7200',
#   '2. high': '166.7300',
#   '3. low': '166.6500',
#   '4. close': '166.7300',
#   '5. volume': '30660'},
#  '2023-04-20 16:15:00': {'1. open': '166.6500',
#   '2. high': '166.7800',
#   '3. low': '166.5500',
#   '4. close': '166.7300',
#   '5. volume': '2227681'},
#  '2023-04-20 16:00:00': {'1. open': '165.8400',
#   '2. high': '166.6700',
#   '3. low': '165.8000',
#   '4. close': '166.6500',
#   '5. volume': '3867994'},
#  '2023-04-20 15:45:00': {'1. open': '165.6250',
#   '2. high': '166.0659',
#   '3. low': '165.6250',
#   '4. close': '165.8300',
#   '5. volume': '2176330'},
#  '2023-04-20 15:30:00': {'1. open': '166.0300',
#   '2. high': '166.0750',
#   '3. low': '165.5600',
#   '4. close': '165.6200',
#   '5. volume': '2503582'},
#  '2023-04-20 15:15:00': {'1. open': '166.5600',
#   '2. high': '166.6400',
#   '3. low': '166.0000',
#   '4. close': '166.0312',
#   '5. volume': '1849409'},
#  '2023-04-20 15:00:00': {'1. open': '166.3400',
#   '2. high': '166.6000',
#   '3. low': '166.2500',
#   '4. close': '166.5600',
#   '5. volume': '1392052'},
#  '2023-04-20 14:45:00': {'1. open': '166.8600',
#   '2. high': '166.8900',
#   '3. low': '166.2301',
#   '4. close': '166.3401',
#   '5. volume': '1838777'},
#  '2023-04-20 14:30:00': {'1. open': '167.3600',
#   '2. high': '167.3800',
#   '3. low': '166.8300',
#   '4. close': '166.8700',
#   '5. volume': '1380328'},
#  '2023-04-20 14:15:00': {'1. open': '167.4700',
#   '2. high': '167.5000',
#   '3. low': '167.2600',
#   '4. close': '167.3628',
#   '5. volume': '1135194'},
#  '2023-04-20 14:00:00': {'1. open': '167.6545',
#   '2. high': '167.7500',
#   '3. low': '167.4500',
#   '4. close': '167.4700',
#   '5. volume': '752043'},
#  '2023-04-20 13:45:00': {'1. open': '167.6100',
#   '2. high': '167.7200',
#   '3. low': '167.4400',
#   '4. close': '167.6599',
#   '5. volume': '923391'},
#  '2023-04-20 13:30:00': {'1. open': '167.8400',
#   '2. high': '167.8400',
#   '3. low': '167.6000',
#   '4. close': '167.6009',
#   '5. volume': '872073'},
#  '2023-04-20 13:15:00': {'1. open': '167.6950',
#   '2. high': '167.8600',
#   '3. low': '167.5600',
#   '4. close': '167.8400',
#   '5. volume': '1084091'},
#  '2023-04-20 13:00:00': {'1. open': '167.4350',
#   '2. high': '167.7400',
#   '3. low': '167.4300',
#   '4. close': '167.7000',
#   '5. volume': '909239'},
#  '2023-04-20 12:45:00': {'1. open': '167.4100',
#   '2. high': '167.8700',
#   '3. low': '167.3800',
#   '4. close': '167.4384',
#   '5. volume': '1389874'},
#  '2023-04-20 12:30:00': {'1. open': '167.1800',
#   '2. high': '167.4900',
#   '3. low': '167.1417',
#   '4. close': '167.4100',
#   '5. volume': '896199'},
#  '2023-04-20 12:15:00': {'1. open': '167.2800',
#   '2. high': '167.3279',
#   '3. low': '166.9600',
#   '4. close': '167.1750',
#   '5. volume': '1110363'},
#  '2023-04-20 12:00:00': {'1. open': '167.3250',
#   '2. high': '167.5400',
#   '3. low': '167.2500',
#   '4. close': '167.2800',
#   '5. volume': '1252937'},
#  '2023-04-20 11:45:00': {'1. open': '167.1424',
#   '2. high': '167.4400',
#   '3. low': '166.9000',
#   '4. close': '167.3299',
#   '5. volume': '1406169'},
#  '2023-04-20 11:30:00': {'1. open': '166.8200',
#   '2. high': '167.1700',
#   '3. low': '166.6200',
#   '4. close': '167.1400',
#   '5. volume': '1461741'},
#  '2023-04-20 11:15:00': {'1. open': '166.8700',
#   '2. high': '166.9500',
#   '3. low': '166.5100',
#   '4. close': '166.8200',
#   '5. volume': '1202593'}}

# %%
#store data into a DataFrame
df_apple1 = pd.DataFrame(apple1).transpose().reset_index()
df_apple1.head()
# Out:
#                  index   1. open   2. high    3. low  4. close 5. volume
# 0  2023-04-21 20:00:00  164.9200  165.0000  164.9200  164.9201      5051
# 1  2023-04-21 19:45:00  164.9400  164.9400  164.9000  164.9000      3592
# 2  2023-04-21 19:30:00  164.9400  164.9400  164.9400  164.9400       246
# 3  2023-04-21 19:15:00  164.9000  164.9600  164.9000  164.9600      1150
# 4  2023-04-21 19:00:00  164.9600  164.9600  164.9100  164.9100      5659

# %%
#Bring in data in DataFrame format
ts2 = TimeSeries(key = API_key, output_format = 'pandas')

# %%
#display new intraday stock data
ts2.get_intraday('AAPL')
# Out:
# (                      1. open   2. high  3. low  4. close  5. volume
#  date
#  2023-04-21 20:00:00  164.9200  165.0000  164.92  164.9201     5051.0
#  2023-04-21 19:45:00  164.9400  164.9400  164.90  164.9000     3592.0
#  2023-04-21 19:30:00  164.9400  164.9400  164.94  164.9400      246.0
#  2023-04-21 19:15:00  164.9000  164.9600  164.90  164.9600     1150.0
#  2023-04-21 19:00:00  164.9600  164.9600  164.91  164.9100     5659.0
#  ...                       ...       ...     ...       ...        ...
#  2023-04-20 12:15:00  167.2800  167.3279  166.96  167.1750  1110363.0
#  2023-04-20 12:00:00  167.3250  167.5400  167.25  167.2800  1252937.0
#  2023-04-20 11:45:00  167.1424  167.4400  166.90  167.3299  1406169.0
#  2023-04-20 11:30:00  166.8200  167.1700  166.62  167.1400  1461741.0
#  2023-04-20 11:15:00  166.8700  166.9500  166.51  166.8200  1202593.0
#
#  [100 rows x 5 columns],
#  {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2023-04-21 20:00:00',
#   '4. Interval': '15min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'})

# %%
#get full amount of intraday stock data for data and meta_data
df_apple2, meta_data = ts2.get_intraday('AAPL', outputsize = 'full')

# %%
#print meta_data
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'AAPL',
#  '3. Last Refreshed': '2023-04-21 20:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
#print data with reset index
df_apple2.reset_index()
# Out:
#                     date  1. open  2. high  3. low  4. close  5. volume
# 0    2023-04-21 20:00:00   164.92   165.00  164.92  164.9201     5051.0
# 1    2023-04-21 19:45:00   164.94   164.94  164.90  164.9000     3592.0
# 2    2023-04-21 19:30:00   164.94   164.94  164.94  164.9400      246.0
# 3    2023-04-21 19:15:00   164.90   164.96  164.90  164.9600     1150.0
# 4    2023-04-21 19:00:00   164.96   164.96  164.91  164.9100     5659.0
# ...                  ...      ...      ...     ...       ...        ...
# 1846 2023-03-13 05:15:00   149.11   149.40  148.86  149.4000    25724.0
# 1847 2023-03-13 05:00:00   150.03   150.03  149.16  149.1600    16187.0
# 1848 2023-03-13 04:45:00   150.13   150.20  150.03  150.0600    13994.0
# 1849 2023-03-13 04:30:00   150.57   150.64  150.21  150.2100    17439.0
# 1850 2023-03-13 04:15:00   150.02   150.98  149.02  150.6000    47512.0
#
# [1851 rows x 6 columns]
